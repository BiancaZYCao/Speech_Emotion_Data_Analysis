# %% [markdown]
# # Data Augmentation
#
# [x] define augmentation operations functions
# [x] conduct 4 types augmentation on training set
# [x] save file and meta-data file

# %% [markdown]
# #   defined the augmentation 4 functions

# %%
import os
import pandas as pd
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt
from IPython.display import Audio
import soundfile as sf
import warnings
import csv

# Suppress the warning
warnings.filterwarnings('ignore', message='PySoundFile failed. Trying audioread instead.')


def noise(data):
    #Calculate the amplitude of the noise
    noise_amp = 0.035*np.random.uniform()*np.amax(data)   
    data_noise = data + noise_amp*np.random.normal(size=data.shape[0])  
    return data_noise

def stretch(data, rate=0.8): 
    # Apply Time stretching (rate can be set to 0.8 to slow down, 2 to speed up)
    data_stretch = librosa.effects.time_stretch(data, rate=0.8)
    return data_stretch
    
def shift(data):
    # Apply time shift (randomly shift time within the range of -5 to 5 milliseconds)
    shift_range = int(np.random.uniform(low=-5, high = 5)*1000)
    return np.roll(data, shift_range)

def pitch(data):
    
    # Trail-1
    # # Shift up by a major third (four steps if bins_per_octave is 12) 上移大三分之一（如果 bins_per_octave 为 12，则上移四步）
    # data_pitch = librosa.effects.pitch_shift(data, sr=sampling_rate, n_steps=4)


    # Trial-2
    #  # Shift down by a tritone (six steps if bins_per_octave is 12) 向下移动一个三全音（如果 bins_per_octave 为 12，则为六步）
    # data_pitch = librosa.effects.pitch_shift(data, sr=sampling_rate, n_steps=-6)   
    
    # Trial-3
    # Shift up by 3 quarter-tones 向上移动 3 个四分音
    data_pitch = librosa.effects.pitch_shift(data, sr=sampling_rate, n_steps=3,
                                         bins_per_octave=24)
       
    return data_pitch


# def pitch(data, sampling_rate, pitch_factor=0.7):      
#     # data_pitch=librosa.effects.pitch_shift(data, sampling_rate, pitch_factor)
#     return data_pitch

# %%
csv_file_path = "dataset_info_combined_v4.csv"  # replace your csv file name
df = pd.read_csv(csv_file_path)

train_file_path = df[df['renamed_file_path'].str.startswith('./dataset/splitted/train/')]['renamed_file_path'].tolist()

for file_path in train_file_path:
    print(file_path)
       
print("The total amount of train dataset:", len(train_file_path))     

#The total amount of train dataset:10982
# Out:
# ./dataset/splitted/train/CREMA-D_1022_ITS_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1037_ITS_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1060_ITS_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1075_ITS_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1073_IOM_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1066_IOM_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1078_IWL_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1029_TAI_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1039_IEO_SAD_MD_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1008_TAI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1018_TSI_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1028_IEO_SAD_HI_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1039_TSI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1064_ITS_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1071_ITS_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1045_ITS_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1018_IWL_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1059_IEO_ANG_MD_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1054_MTI_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1048_IEO_ANG_HI_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1042_ITS_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1019_TAI_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1028_TSI_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1087_IOM_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1039_IEO_HAP_LO_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1018_IEO_FEA_LO_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1079_DFA_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1063_IWW_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1076_IWW_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1068_WSI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1049_WSI_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1059_ITH_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1068_DFA_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1049_DFA_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1079_WSI_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1082_IWW_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1061_ITH_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1074_ITH_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1023_ITH_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1036_ITH_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1005_IEO_DIS_LO_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1010_IEO_DIS_LO_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1084_IEO_SAD_LO_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1076_TIE_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1063_TIE_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1042_TIE_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1079_IWW_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1054_WSI_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1045_TIE_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1083_IEO_FEA_LO_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1019_IWW_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1044_ITH_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1051_ITH_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1065_ITH_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1054_DFA_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1070_ITH_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1067_TIE_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1030_TIE_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1025_TIE_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1043_ITH_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1056_ITH_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1045_IEO_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1079_MTI_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1086_TAI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1027_IEO_DIS_HI_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1032_IEO_DIS_HI_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1062_IWL_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1077_IWL_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1036_IEO_DIS_MD_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1083_TSI_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1023_IEO_DIS_MD_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1005_TSI_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1010_TSI_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1084_IEO_HAP_MD_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1034_TAI_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1021_TAI_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1084_TSI_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1080_IEO_HAP_HI_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1069_IOM_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1082_TAI_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1049_MTI_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1068_MTI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1058_ITS_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1083_IWL_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1079_TAI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1048_IEO_SAD_MD_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1058_TAI_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1086_MTI_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1088_IWL_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1048_TSI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1059_IEO_SAD_HI_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1069_TSI_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1084_IOM_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1046_ITS_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1017_IOM_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1002_IOM_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1011_ITS_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1083_IOM_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1082_MTI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1026_ITS_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1033_ITS_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1068_TAI_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1059_TSI_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1021_ITS_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1034_ITS_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1015_ITS_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1028_IEO_ANG_MD_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1069_IWL_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1039_IEO_ANG_HI_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1030_MTI_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1025_MTI_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1038_WSI_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1019_WSI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1089_TIE_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1086_IWW_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1069_IEO_FEA_LO_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1048_IEO_HAP_LO_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1007_IWW_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1012_IWW_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1008_DFA_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1038_DFA_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1028_ITH_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1019_DFA_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1008_IWW_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1025_WSI_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1034_TIE_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1030_WSI_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1021_TIE_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1086_DFA_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1089_IWW_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1082_WSI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1005_ITH_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1010_ITH_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1061_IEO_DIS_LO_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1074_IEO_DIS_LO_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1047_ITH_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1052_ITH_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1033_TIE_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1026_TIE_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1012_TIE_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1007_TIE_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1027_ITH_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1032_ITH_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1034_IEO_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1021_IEO_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1082_DFA_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1080_IEO_ANG_LO_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1068_IWW_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1030_DFA_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1001_ITH_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1086_WSI_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1014_ITH_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1025_DFA_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1020_ITH_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1035_ITH_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1016_TIE_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1003_TIE_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1054_TIE_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1080_IWL_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1061_TSI_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1074_TSI_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1018_IOM_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1045_TAI_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1008_MTI_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1087_IWL_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1043_IEO_DIS_HI_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1056_IEO_DIS_HI_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1052_IEO_DIS_MD_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1047_IEO_DIS_MD_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1006_IWL_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1013_IWL_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1019_MTI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1038_MTI_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1080_TSI_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1078_IOM_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1029_ITS_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1022_MTI_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1037_MTI_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1086_ITS_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1025_MTI_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1030_MTI_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1011_MTI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1065_IOM_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1088_TSI_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1070_IOM_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1027_IOM_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1032_IOM_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1034_ITS_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1021_ITS_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1084_IOM_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1069_TSI_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1082_ITS_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1088_IWL_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1058_TAI_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1005_IOM_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1010_IOM_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1015_MTI_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1042_MTI_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1023_IOM_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1036_IOM_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1002_IOM_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1017_IOM_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1029_IEO_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1088_IEO_ANG_LO_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1075_IWW_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1060_IWW_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1037_IWW_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1022_IWW_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1028_ITH_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1038_DFA_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1049_TIE_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1015_IWW_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1038_WSI_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1029_TIE_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1033_IWW_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1026_IWW_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1012_IWW_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1018_ITH_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1007_IWW_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1069_IEO_DIS_LO_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1015_WSI_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1087_ITH_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1042_WSI_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1085_TIE_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1022_DFA_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1037_DFA_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1090_TIE_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1035_ITH_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1020_ITH_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1011_DFA_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1025_DFA_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1013_IEO_ANG_LO_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1006_IEO_ANG_LO_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1030_DFA_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1011_WSI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1083_ITH_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1089_IWW_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1030_WSI_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1025_WSI_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1073_IEO_SAD_LO_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1066_IEO_SAD_LO_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1037_WSI_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1026_TIE_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1022_WSI_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1033_TIE_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1055_IEO_HAP_LO_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1040_IEO_HAP_LO_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1042_DFA_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1074_IEO_FEA_LO_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1061_IEO_FEA_LO_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1015_DFA_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1022_TAI_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1037_TAI_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1060_TAI_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1075_TAI_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1051_TSI_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1044_TSI_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1013_TSI_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1006_TSI_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1008_ITS_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1036_IWL_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1023_IWL_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1029_ITS_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1074_IWL_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1061_IWL_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1020_IEO_ANG_MD_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1035_IEO_ANG_MD_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1038_MTI_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1031_IEO_ANG_HI_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1024_IEO_ANG_HI_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1045_TAI_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1014_IWL_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1001_IWL_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1064_TAI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1040_IEO_SAD_MD_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1055_IEO_SAD_MD_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1071_TAI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1074_TSI_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1061_TSI_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1055_TSI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1051_IEO_SAD_HI_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1080_IWL_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1044_IEO_SAD_HI_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1040_TSI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1066_IEO_HAP_MD_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1013_IWL_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1019_ITS_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1042_TAI_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1006_IWL_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1073_IEO_HAP_MD_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1032_IWL_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1047_IEO_FEA_MD_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1052_IEO_FEA_MD_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1027_IWL_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1077_IEO_HAP_HI_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1073_TSI_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1066_TSI_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1062_IEO_HAP_HI_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1056_IEO_FEA_HI_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1043_IEO_FEA_HI_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1060_MTI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1075_MTI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1054_MTI_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1001_IOM_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1014_IOM_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1045_ITS_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1043_IOM_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1056_IOM_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1046_MTI_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1064_MTI_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1071_MTI_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1026_MTI_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1033_MTI_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1066_IOM_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1073_IOM_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1047_IOM_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1052_IOM_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1018_TSI_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1061_IOM_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1074_IOM_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1088_IEO_HAP_HI_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1029_TAI_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1011_IWW_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1049_DFA_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1078_ITH_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1059_ITH_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1046_IWW_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1038_TIE_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1058_IEO_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1076_IWW_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1063_IWW_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1069_ITH_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1042_IWW_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1018_IEO_DIS_LO_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1071_IWW_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1064_IWW_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1049_WSI_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1058_TIE_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1077_IEO_ANG_LO_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1054_DFA_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1062_IEO_ANG_LO_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1051_ITH_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1060_DFA_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1075_DFA_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1044_ITH_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1071_WSI_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1064_WSI_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1033_WSI_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1026_WSI_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1046_DFA_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1042_TIE_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1046_WSI_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1010_IEO_FEA_LO_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1026_DFA_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1033_DFA_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1005_IEO_FEA_LO_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1031_IEO_HAP_LO_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1024_IEO_HAP_LO_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1064_DFA_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1071_DFA_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1083_IEO_DIS_LO_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1054_WSI_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1075_WSI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1060_WSI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1017_IEO_SAD_LO_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1002_IEO_SAD_LO_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1052_IWL_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1058_ITS_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1047_IWL_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1079_ITS_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1044_IEO_ANG_MD_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1051_IEO_ANG_MD_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1010_IWL_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1005_IWL_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1055_IEO_ANG_HI_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1040_IEO_ANG_HI_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1049_MTI_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1046_TAI_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1011_TAI_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1035_TSI_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1020_TSI_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1077_TSI_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1062_TSI_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1056_IWL_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1023_IEO_FEA_MD_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1083_TSI_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1036_IEO_FEA_MD_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1043_IWL_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1002_IEO_HAP_MD_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1026_TAI_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1077_IWL_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1062_IWL_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1068_ITS_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1033_TAI_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1017_IEO_HAP_MD_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1032_IEO_FEA_HI_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1027_IEO_FEA_HI_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1013_IEO_HAP_HI_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1017_TSI_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1002_TSI_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1006_IEO_HAP_HI_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1024_IEO_SAD_MD_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1031_IEO_SAD_MD_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1015_TAI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1070_IWL_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1021_TAI_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1034_TAI_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1065_IWL_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1031_TSI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1035_IEO_SAD_HI_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1020_IEO_SAD_HI_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1024_TSI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1010_TSI_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1005_TSI_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1084_IWL_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1049_MTI_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1059_IOM_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1085_TAI_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1090_TAI_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1087_IEO_HAP_HI_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1083_TSI_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1026_TAI_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1033_TAI_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1083_IEO_HAP_MD_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1017_TSI_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1002_TSI_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1024_IEO_DIS_MD_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1069_IOM_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1084_TSI_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1031_IEO_DIS_MD_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1048_IOM_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1070_IWL_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1065_IWL_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1035_IEO_DIS_HI_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1020_IEO_DIS_HI_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1029_MTI_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1051_ITH_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1044_ITH_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1042_IEO_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1060_TIE_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1075_TIE_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1022_TIE_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1037_TIE_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1077_ITH_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1046_DFA_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1062_ITH_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1056_ITH_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1049_IWW_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1043_ITH_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1042_TIE_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1046_WSI_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1084_IEO_FEA_LO_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1083_IEO_SAD_LO_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1045_TIE_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1064_TIE_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1071_TIE_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1079_IWW_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1073_ITH_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1066_ITH_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1058_IWW_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1017_IEO_DIS_LO_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1002_IEO_DIS_LO_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1031_ITH_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1024_ITH_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1049_DFA_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1029_WSI_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1090_IWW_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1085_IWW_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1078_IEO_ANG_LO_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1018_IEO_SAD_LO_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1029_DFA_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1071_IWW_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1064_IWW_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1058_TIE_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1049_WSI_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1078_TSI_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1080_IOM_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1049_TAI_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1045_ITS_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1046_MTI_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1048_IWL_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1042_ITS_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1076_ITS_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1063_ITS_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1028_IEO_FEA_HI_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1018_TSI_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1030_ITS_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1025_ITS_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1059_IWL_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1061_IOM_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1074_IOM_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1039_IEO_FEA_MD_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1078_IWL_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1029_TAI_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1018_IEO_HAP_MD_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1067_ITS_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1087_TSI_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1028_IOM_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1038_MTI_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1089_ITS_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1014_IWL_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1039_IOM_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1001_IWL_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1040_IEO_DIS_MD_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1018_IOM_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1055_IEO_DIS_MD_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1058_MTI_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1051_IEO_DIS_HI_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1044_IEO_DIS_HI_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1080_IWL_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1042_TAI_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1073_TSI_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1066_TSI_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1087_IWL_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1011_TIE_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1046_TIE_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1038_IWW_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1032_ITH_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1027_ITH_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1022_DFA_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1013_ITH_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1006_ITH_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1037_DFA_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1087_IEO_ANG_LO_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1085_DFA_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1090_DFA_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1035_ITH_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1020_ITH_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1026_IEO_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1033_IEO_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1015_TIE_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1021_TIE_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1034_TIE_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1029_IWW_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1090_WSI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1017_ITH_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1008_IWW_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1002_ITH_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1085_WSI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1055_ITH_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1040_ITH_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1073_IEO_DIS_LO_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1066_IEO_DIS_LO_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1026_TIE_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1037_WSI_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1033_TIE_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1022_WSI_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1038_DFA_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1088_ITH_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1058_WSI_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1058_DFA_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1015_IWW_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1029_TIE_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1038_WSI_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1069_IEO_SAD_LO_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1086_IWW_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1022_MTI_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1037_MTI_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1012_ITS_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1007_ITS_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1039_IWL_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1033_ITS_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1026_ITS_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1085_MTI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1038_TAI_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1090_MTI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1034_ITS_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1021_ITS_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1078_IEO_HAP_HI_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1084_IOM_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1069_TSI_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1059_IEO_FEA_HI_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1054_ITS_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1016_ITS_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1069_IEO_HAP_MD_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1058_TAI_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1003_ITS_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1048_IEO_FEA_MD_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1005_IOM_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1028_IWL_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1010_IOM_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1083_IOM_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1044_IEO_FEA_HI_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1051_IEO_FEA_HI_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1065_IEO_HAP_HI_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1061_TSI_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1074_TSI_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1070_IEO_HAP_HI_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1049_ITS_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1020_IWL_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1018_IOM_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1055_IEO_FEA_MD_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1040_IEO_FEA_MD_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1035_IWL_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1074_IEO_HAP_MD_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1001_IWL_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1045_TAI_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1014_IWL_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1061_IEO_HAP_MD_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1047_TSI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1043_IEO_SAD_HI_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1087_IWL_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1056_IEO_SAD_HI_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1052_TSI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1066_TSI_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1073_TSI_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1076_TAI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1052_IEO_SAD_MD_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1047_IEO_SAD_MD_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1063_TAI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1006_IWL_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1013_IWL_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1042_TAI_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1089_MTI_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1023_IEO_ANG_HI_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1036_IEO_ANG_HI_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1024_IWL_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1031_IWL_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1032_IEO_ANG_MD_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1027_IEO_ANG_MD_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1066_IWL_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1073_IWL_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1043_TSI_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1056_TSI_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1001_TSI_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1014_TSI_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1030_TAI_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1025_TAI_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1029_ITS_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1067_TAI_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1066_IEO_FEA_LO_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1073_IEO_FEA_LO_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1045_DFA_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1047_IEO_HAP_LO_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1052_IEO_HAP_LO_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1008_IWW_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1012_DFA_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1007_DFA_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1034_TIE_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1025_WSI_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1021_TIE_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1030_WSI_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1089_IWW_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1086_TIE_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1061_IEO_SAD_LO_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1074_IEO_SAD_LO_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1022_WSI_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1037_WSI_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1084_ITH_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1003_WSI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1016_WSI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1037_DFA_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1001_IEO_ANG_LO_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1014_IEO_ANG_LO_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1022_DFA_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1016_DFA_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1027_ITH_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1032_ITH_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1003_DFA_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1030_DFA_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1025_DFA_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1082_TIE_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1007_WSI_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1080_ITH_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1012_WSI_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1045_WSI_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1029_TIE_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1008_TIE_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1015_IWW_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1021_IWW_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1034_IWW_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1048_ITH_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1089_DFA_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1086_IWW_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1007_IWW_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1012_IWW_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1019_TIE_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1067_IWW_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1089_WSI_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1025_IWW_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1030_IWW_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1028_ITH_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1010_IOM_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1048_IEO_DIS_MD_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1005_IOM_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1031_IOM_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1024_IOM_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1012_MTI_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1007_MTI_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1088_IWL_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1059_IEO_DIS_HI_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1045_MTI_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1017_IOM_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1002_IOM_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1085_ITS_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1090_ITS_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1083_IOM_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1077_IOM_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1062_IOM_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1026_ITS_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1033_ITS_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1035_IOM_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1020_IOM_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1016_MTI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1003_MTI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1037_MTI_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1022_MTI_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1030_MTI_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1025_MTI_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1002_TSI_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1017_TSI_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1023_TSI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1027_IEO_SAD_HI_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1032_IEO_SAD_HI_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1036_TSI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1062_IWL_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1033_TAI_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1026_TAI_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1077_IWL_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1012_TAI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1036_IEO_SAD_MD_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1023_IEO_SAD_MD_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1007_TAI_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1001_IEO_HAP_HI_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1005_TSI_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1010_TSI_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1014_IEO_HAP_HI_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1020_IEO_FEA_HI_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1035_IEO_FEA_HI_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1038_ITS_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1010_IEO_HAP_MD_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1034_TAI_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1065_IWL_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1070_IWL_FEA_XX_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1021_TAI_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1005_IEO_HAP_MD_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1044_IWL_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1031_IEO_FEA_MD_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1084_TSI_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1024_IEO_FEA_MD_Fear_-1.wav
# ./dataset/splitted/train/CREMA-D_1051_IWL_HAP_XX_Happiness_1.wav
# ./dataset/splitted/train/CREMA-D_1069_IOM_DIS_XX_Disgust_-1.wav
# ./dataset/splitted/train/CREMA-D_1027_TSI_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1032_TSI_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1065_TSI_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1070_TSI_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1088_IOM_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1054_TAI_ANG_XX_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1016_TAI_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1003_TAI_NEU_XX_Neutrality_0.wav
# ./dataset/splitted/train/CREMA-D_1058_ITS_SAD_XX_Sadness_-1.wav
# ./dataset/splitted/train/CREMA-D_1047_IEO_ANG_HI_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1052_IEO_ANG_HI_Anger_-1.wav
# ./dataset/splitted/train/CREMA-D_1040_IWL_NEU_XX_Neutrality_0.wav
# ...
# ./dataset/splitted/train/TESS_YAF_angry_YAF_five_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_raid_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_rain_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_met_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_keen_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_chat_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_food_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_mill_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_dodge_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_dip_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_cause_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_back_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_wheat_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_shout_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_laud_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_live_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_came_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_yearn_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_gun_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_loaf_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_pole_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_long_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_learn_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_thumb_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_perch_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_germ_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_cheek_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_tell_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_search_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_sell_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_kick_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_chalk_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_hole_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_vine_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_door_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_nice_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_chief_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_goal_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_page_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_south_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_jug_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_bean_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_wife_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_good_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_kill_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_time_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_merge_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_bone_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_moon_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_voice_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_base_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_match_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_knock_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_keep_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_shirt_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_sour_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_walk_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_thin_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_pike_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_YAF_angry_YAF_sheep_angry_Anger_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_gaze_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_neat_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_mouse_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_page_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_check_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_bite_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_chat_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_knock_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_late_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_search_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_whip_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_tape_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_talk_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_bean_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_when_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_king_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_south_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_reach_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_hire_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_wag_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_room_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_fat_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_mill_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_said_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_name_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_cause_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_puff_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_home_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_tip_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_sour_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_germ_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_mop_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_ripe_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_hash_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_five_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_juice_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_date_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_should_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_have_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_merge_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_nice_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_keep_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_pad_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_wheat_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_yes_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_fall_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_bath_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_lid_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_tell_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_laud_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_limb_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_mess_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_sail_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_shawl_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_gin_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_nag_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_raise_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_tire_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_chain_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_live_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_book_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_sell_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_jail_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_luck_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_soap_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_keen_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_long_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_chair_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_haze_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_youth_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_sub_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_cheek_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_food_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_love_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_hush_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_pool_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_hit_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_deep_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_time_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_team_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_cool_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_red_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_soup_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_pass_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_ring_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_door_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_witch_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_get_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_pike_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_turn_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_dime_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_wife_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_yearn_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_death_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_vine_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_sure_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_wash_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_mode_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_size_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_base_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_thin_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_dodge_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_kick_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_dead_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_make_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_half_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_white_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_gap_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_thumb_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_hate_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_match_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_rot_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_note_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_lease_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_hurl_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_wire_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_peg_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_phone_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_mood_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_such_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_lot_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_bought_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_shall_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_burn_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_ditch_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_near_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_loaf_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_pick_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_life_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_fit_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_tough_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_lore_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_third_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_pain_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_rose_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_shirt_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_read_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_sheep_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_far_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_mob_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_doll_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_raid_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_good_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_gun_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_bone_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_seize_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_jug_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_pole_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_numb_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_beg_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_dab_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_boat_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_kill_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_gas_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_hall_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_which_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_walk_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_week_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_take_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_back_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_perch_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_judge_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_jar_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_learn_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_chief_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_choice_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_shout_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_void_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_dog_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_rag_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_dip_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_rush_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_shack_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_join_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_fail_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_tool_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_goose_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_pearl_sad_Sadness_-1.wav
# ./dataset/splitted/train/TESS_OAF_Sad_OAF_rain_sad_Sadness_-1.wav
# The total amount of train dataset: 10982

# %% [markdown]
# #   1- Noise Injection on 10982 train data

# %%
# create new directory to store train data after augmented
new_directory = "./dataset/splitted/Train_Data_Augmentation/NoiseInjection"    # change to your own directory
# new_directory = "./dataset/train/Data_Augmentation/Stretch"    # change to your own directory
# new_directory = "./dataset/train/Data_Augmentation/Shift"    # change to your own directory
# new_directory = "./dataset/train/Data_Augmentation/Pitch"    # change to your own directory


if not os.path.exists(new_directory):
    os.makedirs(new_directory)


# add noise on each wav files
for file_path in train_file_path:
    try:
        # load wav file
        data, sampling_rate = librosa.load(file_path, sr=16000)   
        # add noise
        noisy_data = noise(data)
        
        #rename new noise added wav file
        file_name = os.path.basename(file_path)
        new_file_path = os.path.join(new_directory, file_name.replace('.wav', '_NoiseInjection.wav'))  # change your new wav file name
        
        # Save processed audio data as a new WAV file
        sf.write(new_file_path, noisy_data, sampling_rate)
    except FileNotFoundError:
        print(f"File not found: {file_path}. Skipping...")

# %% [markdown]
# #   2- Time Stretch on 10982 train data

# %%
# create new directory to store train data after augmented
new_directory = "./dataset/splitted/Train_Data_Augmentation/Stretch"    # change to your own directory


# Ensure the directory exists, create if it doesn't
if not os.path.exists(new_directory):
    os.makedirs(new_directory)

for file_path in train_file_path:
    try:
        # Load the WAV file
        data, sampling_rate = librosa.load(file_path, sr=16000)
        
        # Time stretch (modify the audio time without changing pitch)
        x = stretch(data)  # Uncomment this line if you've defined the stretch function
        
        # Generate a new file name and add it to the new directory
        file_name = os.path.basename(file_path)
        new_file_path = os.path.join(new_directory, file_name.replace('.wav', '_Stretch.wav'))
        
        # Save the processed audio data as a new WAV file
        sf.write(new_file_path, x, sampling_rate)
    except FileNotFoundError:
        print(f"File not found: {file_path}. Skipping...")

# %% [markdown]
# #   3- Time Shift on 10982 train data

# %%
# Set the directory for augmented data
new_directory = "./dataset/splitted/Train_Data_Augmentation/Shift"

# Ensure the directory exists, create if it doesn't
if not os.path.exists(new_directory):
    os.makedirs(new_directory)

# Process each WAV file
for file_path in train_file_path:
    try:
        # Load the WAV file
        data, sampling_rate = librosa.load(file_path, sr=16000)
        
        # Apply time shift (randomly shift time within the range of -5 to 5 milliseconds)
        x = shift(data)
        
        # Generate a new file name and add it to the new directory
        file_name = os.path.basename(file_path)
        new_file_path = os.path.join(new_directory, file_name.replace('.wav', '_Shift.wav'))
        
        # Save the processed audio data as a new WAV file
        sf.write(new_file_path, x, sampling_rate)
    except FileNotFoundError:
        print(f"File not found: {file_path}. Skipping...")
    except Exception as e:
        print(f"An error occurred while processing {file_path}: {e}")

# %% [markdown]
# #   4 - Pitch Shift on 10982 train data

# %%
# Set the directory for augmented data
new_directory = "./dataset/splitted/Train_Data_Augmentation/Pitch" 

# Ensure the directory exists, create if it doesn't
if not os.path.exists(new_directory):
    os.makedirs(new_directory)
    
# Process each WAV file   
for file_path in train_file_path:
    try:
        # Load the WAV file
        data, sampling_rate = librosa.load(file_path, sr=16000)
        
        # Apply pitch
        x=pitch(data)
        
        # Generate a new file name and add it to the new directory
        file_name = os.path.basename(file_path)
        new_file_path = os.path.join(new_directory, file_name.replace('.wav', '_Pitch.wav'))
        
        # Save the processed audio data as a new WAV file
        sf.write(new_file_path, x, sampling_rate)
    except FileNotFoundError:
        print(f"File not found: {file_path}. Skipping...")
    except Exception as e:
        print(f"An error occurred while processing {file_path}: {e}")

# %% [markdown]
# # manually replace \ with /

# %% [markdown]
# #   Export all generated augmented WAV files  ----- path + attitudes(augmentation_types, sentiment_values & emotional_categories)

# %%
import os
import csv
import pandas as pd

# Define the folder path where augmented WAV files are stored
folder_path = './dataset/splitted/Train_Data_Augmentation'

# Get the list of subfolders containing augmented WAV files
subfolders = [os.path.join(folder_path, f) for f in os.listdir(folder_path) if os.path.isdir(os.path.join(folder_path, f))]

# Initialize a list to store the paths of all augmented WAV files
wav_files = []

# Iterate through each subfolder to collect the paths of WAV files
for subfolder in subfolders:
    wav_files.extend([os.path.join(subfolder, f) for f in os.listdir(subfolder) if f.endswith('.wav')])

# Define the CSV file path to store the generated data
csv_file_path = 'train_data_augmentation_attitudes_final.csv'

# Open the CSV file for writing
with open(csv_file_path, 'w', newline='') as csvfile:
    writer = csv.writer(csvfile)
    
    # Write the header row
    writer.writerow(['File_Name', 'Augmentation_Type', 'Sentiment_Value', 'Emotional_Category'])
    
    # Iterate through each WAV file to extract its attributes and write them to the CSV file
    for wav_file in wav_files:
        file_name = os.path.basename(wav_file)
        parts = file_name.split('_')
        
        # Extract augmentation type, sentiment value, and emotional category from the file name
        augmentation_type = parts[-1].split('.')[0]  # Remove the file extension
        sentiment_value = parts[-2]
        emotional_category = parts[-3]
        
        # Write the file name and its attributes to the CSV file
        writer.writerow([wav_file, augmentation_type, sentiment_value, emotional_category])

# Print a message indicating that the CSV file has been generated
print("Train data augmentation attitudes CSV file generated:", csv_file_path)
# Out:
# Train data augmentation attitudes CSV file generated: train_data_augmentation_attitudes_final.csv
