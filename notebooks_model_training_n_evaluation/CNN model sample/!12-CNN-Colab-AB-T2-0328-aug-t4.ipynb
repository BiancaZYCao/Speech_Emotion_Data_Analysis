# %%
import numpy as np
import pandas as pd
import glob
import os, sys
import matplotlib.pyplot as plt
import time
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)
VERSION = 4
RANDOM_SEED = 7

# %%
# !pip install tensorflow

# %% [markdown]
# ## Load data

# %%
from google.colab import drive
drive.mount('/content/gdrive')

import os
os.chdir('/content/gdrive/My Drive/')
# !ls
# Out:
# Mounted at /content/gdrive
#  12_experiment_models-CNN-20240316-v4-aug.ipynb			      CNN1-models
#  12_experiment_models-CNN-20240316-v4-aug-v2.ipynb		      CNN2-models
#  12_experiment_models-CNN-Colab-AB-0316-aug-v3a.ipynb		     'Colab Notebooks'
# '12_experiment_models-CNN-Colab-AB-0316-aug-v3-model2 tuning.ipynb'   data_extracted_features

# %% [markdown]
# ### Load Data - downsampled

# %%
# df_joint_train_org   = pd.read_csv(f'./data_extracted_features/cache_all_features_train_V{VERSION}.csv')
# df_joint_train_org   = df_joint_train_org.drop(columns=['GNE_max_gne','GNE_mean_gne','GNE_stddev_gne','GNE_sum_gne'])

# df_joint_test_org = pd.read_csv(f'./data_extracted_features/cache_all_features_test_V{VERSION}.csv').drop(
#     columns=['GNE_max_gne','GNE_mean_gne','GNE_stddev_gne','GNE_sum_gne'])

# print("shape of train set: ", df_joint_train_org.shape)
# print("shape of test  set: ", df_joint_test_org.shape)


# df_joint_train  = pd.read_csv(f'./data_extracted_features/cache_train_V4_resampled_2500.csv')
df_joint_test = pd.read_csv(f'./data_extracted_features/cache_all_features_test_V4.csv')

# print("shape of train set: ", df_joint_train.shape)
print("shape of test  set: ", df_joint_test.shape)

df_joint_train_aug  = pd.read_csv(f'./data_extracted_features/cache_train_V4_augmented.csv')
feature_column_names = [i for i in df_joint_train_aug.columns \
                        if i not in ['file_path','renamed_file_path','split','sentiment_value','emotional_category']]

print("shape of train set: ", df_joint_train_aug.shape)
df_joint_train_aug.groupby('sentiment_value')['file_path'].count()
# Out:
# shape of test  set:  (1180, 1550)
# shape of train set:  (24885, 1546)
# sentiment_value
# -1    7999
#  0    8560
#  1    8326
# Name: file_path, dtype: int64

# %% [markdown]
# ### best guess feature combinations

# %%
# generate selected features
def generate_selected_features_by_type(feature_column_names,input,stats,number=1):
    selected_result = []
    for name in feature_column_names:
        if input+"_"+stats in name:
            selected_result.append(name)
    if number < len(selected_result):
        selected_result = selected_result[:number]
    return selected_result

# list all the possible features for future selection during model training
feature_MFCC20_mean = generate_selected_features_by_type(feature_column_names,"mfcc","mean",20)
feature_MFCC20_med  = generate_selected_features_by_type(feature_column_names,"mfcc","median",20)
feature_MFCC20_std  = generate_selected_features_by_type(feature_column_names,"mfcc","std",20)
feature_MFCC20_min  = generate_selected_features_by_type(feature_column_names,"mfcc","p10",20)
feature_MFCC20_max  = generate_selected_features_by_type(feature_column_names,"mfcc","p90",20)

feature_MFCC40_mean = generate_selected_features_by_type(feature_column_names,"mfcc","mean",40)
feature_MFCC40_med  = generate_selected_features_by_type(feature_column_names,"mfcc","median",40)
feature_MFCC40_std  = generate_selected_features_by_type(feature_column_names,"mfcc","std",40)
feature_MFCC40_min  = generate_selected_features_by_type(feature_column_names,"mfcc","p10",40)
feature_MFCC40_max  = generate_selected_features_by_type(feature_column_names,"mfcc","p90",40)

feature_MFCC60_mean = generate_selected_features_by_type(feature_column_names,"mfcc","mean",60)
feature_MFCC60_med  = generate_selected_features_by_type(feature_column_names,"mfcc","median",60)
feature_MFCC60_std  = generate_selected_features_by_type(feature_column_names,"mfcc","std",60)
feature_MFCC60_min  = generate_selected_features_by_type(feature_column_names,"mfcc","p10",60)
feature_MFCC60_max  = generate_selected_features_by_type(feature_column_names,"mfcc","p90",60)

feature_chroma_mean = generate_selected_features_by_type(feature_column_names,"chroma","mean",12)
feature_chroma_med  = generate_selected_features_by_type(feature_column_names,"chroma","median",12)
feature_chroma_std  = generate_selected_features_by_type(feature_column_names,"chroma","std",12)
feature_chroma_min  = generate_selected_features_by_type(feature_column_names,"chroma","p10",12)
feature_chroma_max  = generate_selected_features_by_type(feature_column_names,"chroma","p90",12)

feature_MEL32_mean = generate_selected_features_by_type(feature_column_names,"mel32","mean",32)
feature_MEL32_med  = generate_selected_features_by_type(feature_column_names,"mel32","median",32)
feature_MEL32_std  = generate_selected_features_by_type(feature_column_names,"mel32","std",32)
feature_MEL32_min  = generate_selected_features_by_type(feature_column_names,"mel32","p10",32)
feature_MEL32_max  = generate_selected_features_by_type(feature_column_names,"mel32","p90",32)

feature_MEL64_mean = generate_selected_features_by_type(feature_column_names,"mel64","mean",64)
feature_MEL64_med  = generate_selected_features_by_type(feature_column_names,"mel64","median",64)
feature_MEL64_std  = generate_selected_features_by_type(feature_column_names,"mel64","std",64)
feature_MEL64_min  = generate_selected_features_by_type(feature_column_names,"mel64","p10",64)
feature_MEL64_max  = generate_selected_features_by_type(feature_column_names,"mel64","p90",64)

feature_MEL128_mean = generate_selected_features_by_type(feature_column_names,"mel128","mean",128)
feature_MEL128_med  = generate_selected_features_by_type(feature_column_names,"mel128","median",128)
feature_MEL128_std  = generate_selected_features_by_type(feature_column_names,"mel128","std",128)
feature_MEL128_min  = generate_selected_features_by_type(feature_column_names,"mel128","p10",128)
feature_MEL128_max  = generate_selected_features_by_type(feature_column_names,"mel128","p90",128)

feature_MEL32  = generate_selected_features_by_type(feature_column_names,"mel32","",32*5)
feature_MEL64  = generate_selected_features_by_type(feature_column_names,"mel64","",64*5)
feature_MEL128 = generate_selected_features_by_type(feature_column_names,"mel128","",128*5)
feature_zcr    = generate_selected_features_by_type(feature_column_names,"zcr","",5)
feature_rms    = generate_selected_features_by_type(feature_column_names,"rms","",5)
feature_chroma = generate_selected_features_by_type(feature_column_names,"chroma","",12*5)
feature_intensity   = generate_selected_features_by_type(feature_column_names,"Intensity","",9)
feature_pitch    = generate_selected_features_by_type(feature_column_names,"Pitch","",12)
feature_GNE      = generate_selected_features_by_type(feature_column_names,"GNE","",4)
feature_HNR      = generate_selected_features_by_type(feature_column_names,"HNR","",6)
feature_jitter   = generate_selected_features_by_type(feature_column_names,"Jitter","",1)
feature_shimmer  = generate_selected_features_by_type(feature_column_names,"Shimmer","",1)
feature_spectrum = generate_selected_features_by_type(feature_column_names,"Spectrum","",9)
feature_formant  = generate_selected_features_by_type(feature_column_names,"Formant","",14)

mfcc20a = feature_MFCC20_mean + feature_MFCC20_std
mfcc20b = feature_MFCC20_med + feature_MFCC20_std
mfcc20c = feature_MFCC20_mean + feature_MFCC20_min + feature_MFCC20_max
mfcc20d = feature_MFCC20_med + feature_MFCC20_min + feature_MFCC20_max
mfcc20e = feature_MFCC20_mean + feature_MFCC20_std + feature_MFCC20_min + feature_MFCC20_max
mfcc20f = feature_MFCC20_med + feature_MFCC20_std + feature_MFCC20_min + feature_MFCC20_max

mfcc40a = feature_MFCC40_mean + feature_MFCC40_std
mfcc40b = feature_MFCC40_med + feature_MFCC40_std
mfcc40c = feature_MFCC40_mean + feature_MFCC40_min + feature_MFCC40_max
mfcc40d = feature_MFCC40_med + feature_MFCC40_min + feature_MFCC40_max
mfcc40e = feature_MFCC40_mean + feature_MFCC40_std + feature_MFCC40_min + feature_MFCC40_max
mfcc40f = feature_MFCC40_med + feature_MFCC40_std + feature_MFCC40_min + feature_MFCC40_max

mfcc60a = feature_MFCC60_mean + feature_MFCC60_std
mfcc60b = feature_MFCC60_med + feature_MFCC60_std
mfcc60c = feature_MFCC60_mean + feature_MFCC60_min + feature_MFCC60_max
mfcc60d = feature_MFCC60_med + feature_MFCC60_min + feature_MFCC60_max
mfcc60e = feature_MFCC60_mean + feature_MFCC60_std + feature_MFCC60_min + feature_MFCC60_max
mfcc60f = feature_MFCC60_med + feature_MFCC60_std + feature_MFCC60_min + feature_MFCC60_max

mel32a = feature_MEL32_mean + feature_MEL32_std
mel32b = feature_MEL32_med + feature_MEL32_std
mel32c = feature_MEL32_mean + feature_MEL32_min + feature_MEL32_max
mel32d = feature_MEL32_med + feature_MEL32_min + feature_MEL32_max
mel32e = feature_MEL32_mean + feature_MEL32_std + feature_MEL32_min + feature_MEL32_max
mel32f = feature_MEL32_med + feature_MEL32_std + feature_MEL32_min + feature_MEL32_max

mel64a = feature_MEL64_mean + feature_MEL64_std
mel64b = feature_MEL64_med + feature_MEL64_std
mel64c = feature_MEL64_mean + feature_MEL64_min + feature_MEL64_max
mel64d = feature_MEL64_med + feature_MEL64_min + feature_MEL64_max
mel64e = feature_MEL64_mean + feature_MEL64_std + feature_MEL64_min + feature_MEL64_max
mel64f = feature_MEL64_med + feature_MEL64_std + feature_MEL64_min + feature_MEL64_max

mel128a = feature_MEL128_mean + feature_MEL128_std
mel128b = feature_MEL128_med + feature_MEL128_std
mel128c = feature_MEL128_mean + feature_MEL128_min + feature_MEL128_max
mel128d = feature_MEL128_med + feature_MEL128_min + feature_MEL128_max
mel128e = feature_MEL128_mean + feature_MEL128_std + feature_MEL128_min + feature_MEL128_max
mel128f = feature_MEL128_med + feature_MEL128_std + feature_MEL128_min + feature_MEL128_max

feature_MFCC20_mean  = generate_selected_features_by_type(feature_column_names,"mfcc","mean",20)
feature_MFCC20_std   = generate_selected_features_by_type(feature_column_names,"mfcc","std",20)
feature_mel32_median = generate_selected_features_by_type(feature_column_names,"mel32","median",32)
feature_mel32_std    = generate_selected_features_by_type(feature_column_names,"mel32","std",32)
feature_zcr_stats    = generate_selected_features_by_type(feature_column_names,"zcr","",5)
feature_rms_stats    = generate_selected_features_by_type(feature_column_names,"rms","",5)
selected_spect = ['Spectrum_band_energy_difference','Spectrum_band_density_difference','Spectrum_center_of_gravity_spectrum','Spectrum_skewness_spectrum','Spectrum_kurtosis_spectrum', 'Spectrum_stddev_spectrum','Spectrum_band_density', 'Spectrum_band_energy']
selected_formant = ['Formant_f1_mean','Formant_f1_median','Formant_f3_mean','Formant_fitch_vtl','Formant_mff','Formant_formant_dispersion']
selected_pitch = ['Pitch_pitch_slope_without_octave_jumps', 'Pitch_q3_pitch','Pitch_stddev_pitch', 'Pitch_mean_absolute_pitch_slope','Pitch_mean_pitch', 'Pitch_max_pitch', 'Pitch_q1_pitch', 'Pitch_min_pitch']
selected_intensity = ['Intensity_max_intensity', 'Intensity_q3_intensity','Intensity_median_intensity', 'Intensity_mean_intensity', 'Intensity_stddev_intensity','Intensity_relative_max_intensity_time']
selected_HNR = ['HNR_stddev_hnr', 'HNR_mean_hnr','HNR_relative_min_hnr_time','HNR_max_hnr']
selected_prosody = selected_intensity + selected_pitch # + ['Local Jitter','Local Shimmer']
selected_feature_names = feature_MFCC20_mean + feature_MFCC20_std + feature_mel32_median + feature_mel32_std + \
                        feature_zcr_stats + feature_rms_stats + selected_intensity + selected_pitch
selected_feature_names2 = mel128f + mel64f + mfcc60e + feature_zcr + feature_rms + feature_chroma + feature_intensity + feature_pitch + feature_spectrum

# %%
# default use augmented training set and balanced test set
X_train = df_joint_train_aug[selected_feature_names]
X_train2 = df_joint_train_aug[selected_feature_names2]
y_train_s = df_joint_train_aug['sentiment_value']
y_train_e = df_joint_train_aug['emotional_category']

from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
y_e_num = label_encoder.fit_transform(y_train_e)
y_train_e_num = label_encoder.fit_transform(y_train_e)

X_test = df_joint_test[selected_feature_names]
X_test2 = df_joint_test[selected_feature_names2]
y_test_s = df_joint_test['sentiment_value']
y_test_e = df_joint_test['emotional_category']

y_test_e_num = label_encoder.fit_transform(y_test_e)

# Convert x_train to float32
X_train_cnn = np.expand_dims(X_train, axis=2).astype(np.float32)
X_train_cnn2 = np.expand_dims(X_train2, axis=2).astype(np.float32)

X_test_cnn = np.expand_dims(X_test, axis=2).astype(np.float32)
X_test_cnn2 = np.expand_dims(X_test2, axis=2).astype(np.float32)

y_train_e_cnn = y_train_e_num.astype(np.float32)
y_train_s_cnn = y_train_s.astype(np.float32)
y_test_e_cnn = y_test_e_num.astype(np.float32)
y_test_s_cnn = y_test_s.astype(np.float32)

from keras.utils import to_categorical

y_train_e_cnn_one_hot = to_categorical(y_train_e_cnn, num_classes=8)
y_test_e_cnn_one_hot = to_categorical(y_test_e_cnn, num_classes=8)

# %%
X_train.shape, X_test.shape
# Out:
# ((24885, 128), (1180, 128))

# %% [markdown]
# ## CNN Model
# data loading
# and model structure

# %% [markdown]
# ### data loading

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from matplotlib.pyplot import specgram
import keras
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding
from keras.layers import LSTM
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.utils import to_categorical
from keras.layers import Input, Flatten, Dropout, Activation
from keras.layers import Conv1D, MaxPooling1D, AveragePooling1D,BatchNormalization
from keras.models import Model
from keras.callbacks import ModelCheckpoint
from sklearn.metrics import confusion_matrix
from tensorflow.keras import layers,Sequential
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import layers,Sequential
from keras.utils import to_categorical
import tensorflow as tf
print(tf.__version__)


model = Sequential()
input_shape_1 = X_train_cnn.shape[1]
model.add(Conv1D(32, 5,padding='same',input_shape=(input_shape_1,1)))
model.add(layers.Conv1D(64, 5,padding='same',activation="relu"))
model.add(layers.Conv1D(128, 11,padding='same',activation="relu"))
model.add(layers.Dropout(0.33))
model.add(layers.MaxPooling1D(pool_size=(4)))
model.add(layers.Conv1D(128, 11,padding='same',activation="relu"))
model.add(layers.Conv1D(64, 5,padding='same',activation="relu"))
model.add(layers.Conv1D(32, 5,padding='same',activation="relu"))
model.add(layers.MaxPooling1D(pool_size=(4)))
model.add(layers.Dropout(0.3))
model.add(layers.Flatten())
model.add(layers.Dense(10,activation="softmax"))
model.summary()

# model.add(Activation('relu'))
# model.add(Dropout(0.2))
# model.add(Conv1D(128, 8,padding='same',))
# model.add(Activation('relu'))
# model.add(MaxPooling1D(pool_size=(3)))
# model.add(Dropout(0.2))
# model.add(Conv1D(64, 4,padding='same',))
# model.add(Activation('relu'))
# model.add(Flatten())
# model.add(Dense(10))
# model.add(Activation('softmax'))
# opt = keras.optimizers.RMSprop(lr=0.00005, rho=0.9, epsilon=None)  if use RMSprop, encountered error,I use Adam optimizers now
# Out:
# 2.15.0
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 128, 32)           192
#
#  conv1d_1 (Conv1D)           (None, 128, 64)           10304
#
#  conv1d_2 (Conv1D)           (None, 128, 128)          90240
#
#  dropout (Dropout)           (None, 128, 128)          0
#
#  max_pooling1d (MaxPooling1  (None, 32, 128)           0
#  D)
#
#  conv1d_3 (Conv1D)           (None, 32, 128)           180352
#
#  conv1d_4 (Conv1D)           (None, 32, 64)            41024
#
#  conv1d_5 (Conv1D)           (None, 32, 32)            10272
#
#  max_pooling1d_1 (MaxPoolin  (None, 8, 32)             0
#  g1D)
#
#  dropout_1 (Dropout)         (None, 8, 32)             0
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 10)                2570
#
# =================================================================
# Total params: 334954 (1.28 MB)
# Trainable params: 334954 (1.28 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import LearningRateScheduler

# Define the learning rate scheduler function
def lr_scheduler(epoch, lr):
    decay_rate = 0.9
    decay_step = 20
    if epoch % decay_step == 0 and epoch:
        return lr * decay_rate
    return lr

# Create a LearningRateScheduler callback
lr_schedule = LearningRateScheduler(lr_scheduler)

# Define the learning rate you want to use
initial_learning_rate = 0.000026
LR = 0.00006

optimizer = Adam(learning_rate=initial_learning_rate)

checkpointer = ModelCheckpoint(filepath="./CNN1-models/0328-t4.hdf5", verbose=1, save_best_only=True)

model.compile(loss='sparse_categorical_crossentropy',
              optimizer=tf.keras.optimizers.Adam(learning_rate = LR),  # changed from opt to Adam()
              metrics=['accuracy'])

# %%
# cnnhistory=model.fit(X_train_cnn, y_train_e_cnn, batch_size=128, epochs=200, validation_data=(X_test_cnn, y_test_e_cnn))

cnnhistory=model.fit(X_train_cnn, y_train_e_cnn, batch_size=256, epochs=226, validation_data=(X_test_cnn, y_test_e_cnn ), callbacks=([lr_schedule], [checkpointer]))
# Out:
# Epoch 1/226
# 98/98 [==============================] - ETA: 0s - loss: 2.9286 - accuracy: 0.3068
# Epoch 1: val_loss improved from inf to 1.81716, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 12s 42ms/step - loss: 2.9286 - accuracy: 0.3068 - val_loss: 1.8172 - val_accuracy: 0.2932 - lr: 6.0000e-05
# Epoch 2/226
# 97/98 [============================>.] - ETA: 0s - loss: 1.6423 - accuracy: 0.4278
# Epoch 2: val_loss improved from 1.81716 to 1.67444, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 17ms/step - loss: 1.6425 - accuracy: 0.4277 - val_loss: 1.6744 - val_accuracy: 0.3017 - lr: 6.0000e-05
# Epoch 3/226
# 97/98 [============================>.] - ETA: 0s - loss: 1.5225 - accuracy: 0.4605
# Epoch 3: val_loss improved from 1.67444 to 1.59992, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 17ms/step - loss: 1.5219 - accuracy: 0.4606 - val_loss: 1.5999 - val_accuracy: 0.3305 - lr: 6.0000e-05
# Epoch 4/226
# 96/98 [============================>.] - ETA: 0s - loss: 1.4373 - accuracy: 0.4875
# Epoch 4: val_loss improved from 1.59992 to 1.51013, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 19ms/step - loss: 1.4374 - accuracy: 0.4873 - val_loss: 1.5101 - val_accuracy: 0.3814 - lr: 6.0000e-05
# Epoch 5/226
# 96/98 [============================>.] - ETA: 0s - loss: 1.3857 - accuracy: 0.5045
# Epoch 5: val_loss improved from 1.51013 to 1.48707, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 17ms/step - loss: 1.3856 - accuracy: 0.5042 - val_loss: 1.4871 - val_accuracy: 0.3890 - lr: 6.0000e-05
# Epoch 6/226
# 96/98 [============================>.] - ETA: 0s - loss: 1.3389 - accuracy: 0.5221
# Epoch 6: val_loss improved from 1.48707 to 1.42678, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 17ms/step - loss: 1.3394 - accuracy: 0.5220 - val_loss: 1.4268 - val_accuracy: 0.4483 - lr: 6.0000e-05
# Epoch 7/226
# 96/98 [============================>.] - ETA: 0s - loss: 1.3074 - accuracy: 0.5303
# Epoch 7: val_loss improved from 1.42678 to 1.41104, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 16ms/step - loss: 1.3080 - accuracy: 0.5300 - val_loss: 1.4110 - val_accuracy: 0.4508 - lr: 6.0000e-05
# Epoch 8/226
# 97/98 [============================>.] - ETA: 0s - loss: 1.2793 - accuracy: 0.5403
# Epoch 8: val_loss improved from 1.41104 to 1.37853, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 17ms/step - loss: 1.2794 - accuracy: 0.5402 - val_loss: 1.3785 - val_accuracy: 0.4720 - lr: 6.0000e-05
# Epoch 9/226
# 95/98 [============================>.] - ETA: 0s - loss: 1.2483 - accuracy: 0.5488
# Epoch 9: val_loss improved from 1.37853 to 1.33484, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 17ms/step - loss: 1.2490 - accuracy: 0.5487 - val_loss: 1.3348 - val_accuracy: 0.5093 - lr: 6.0000e-05
# Epoch 10/226
# 95/98 [============================>.] - ETA: 0s - loss: 1.2338 - accuracy: 0.5558
# Epoch 10: val_loss did not improve from 1.33484
# 98/98 [==============================] - 2s 16ms/step - loss: 1.2326 - accuracy: 0.5562 - val_loss: 1.3388 - val_accuracy: 0.4881 - lr: 6.0000e-05
# Epoch 11/226
# 95/98 [============================>.] - ETA: 0s - loss: 1.2037 - accuracy: 0.5643
# Epoch 11: val_loss improved from 1.33484 to 1.31550, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 18ms/step - loss: 1.2043 - accuracy: 0.5642 - val_loss: 1.3155 - val_accuracy: 0.5085 - lr: 6.0000e-05
# Epoch 12/226
# 97/98 [============================>.] - ETA: 0s - loss: 1.1839 - accuracy: 0.5744
# Epoch 12: val_loss improved from 1.31550 to 1.30429, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 19ms/step - loss: 1.1837 - accuracy: 0.5745 - val_loss: 1.3043 - val_accuracy: 0.5059 - lr: 6.0000e-05
# Epoch 13/226
# 95/98 [============================>.] - ETA: 0s - loss: 1.1620 - accuracy: 0.5799
# Epoch 13: val_loss improved from 1.30429 to 1.26848, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 16ms/step - loss: 1.1615 - accuracy: 0.5800 - val_loss: 1.2685 - val_accuracy: 0.5322 - lr: 6.0000e-05
# Epoch 14/226
# 97/98 [============================>.] - ETA: 0s - loss: 1.1530 - accuracy: 0.5847
# Epoch 14: val_loss improved from 1.26848 to 1.25648, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 17ms/step - loss: 1.1533 - accuracy: 0.5847 - val_loss: 1.2565 - val_accuracy: 0.5458 - lr: 6.0000e-05
# Epoch 15/226
# 97/98 [============================>.] - ETA: 0s - loss: 1.1365 - accuracy: 0.5934
# Epoch 15: val_loss improved from 1.25648 to 1.24658, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 17ms/step - loss: 1.1367 - accuracy: 0.5932 - val_loss: 1.2466 - val_accuracy: 0.5373 - lr: 6.0000e-05
# Epoch 16/226
# 96/98 [============================>.] - ETA: 0s - loss: 1.1162 - accuracy: 0.5991
# Epoch 16: val_loss improved from 1.24658 to 1.22479, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 17ms/step - loss: 1.1177 - accuracy: 0.5986 - val_loss: 1.2248 - val_accuracy: 0.5458 - lr: 6.0000e-05
# Epoch 17/226
# 96/98 [============================>.] - ETA: 0s - loss: 1.1071 - accuracy: 0.6050
# Epoch 17: val_loss did not improve from 1.22479
# 98/98 [==============================] - 2s 16ms/step - loss: 1.1074 - accuracy: 0.6049 - val_loss: 1.2388 - val_accuracy: 0.5508 - lr: 6.0000e-05
# Epoch 18/226
# 97/98 [============================>.] - ETA: 0s - loss: 1.0931 - accuracy: 0.6076
# Epoch 18: val_loss improved from 1.22479 to 1.20841, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 17ms/step - loss: 1.0928 - accuracy: 0.6078 - val_loss: 1.2084 - val_accuracy: 0.5602 - lr: 6.0000e-05
# Epoch 19/226
# 97/98 [============================>.] - ETA: 0s - loss: 1.0798 - accuracy: 0.6130
# Epoch 19: val_loss did not improve from 1.20841
# 98/98 [==============================] - 2s 18ms/step - loss: 1.0802 - accuracy: 0.6128 - val_loss: 1.2202 - val_accuracy: 0.5602 - lr: 6.0000e-05
# Epoch 20/226
# 96/98 [============================>.] - ETA: 0s - loss: 1.0696 - accuracy: 0.6168
# Epoch 20: val_loss improved from 1.20841 to 1.17700, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 18ms/step - loss: 1.0681 - accuracy: 0.6171 - val_loss: 1.1770 - val_accuracy: 0.5746 - lr: 6.0000e-05
# Epoch 21/226
# 97/98 [============================>.] - ETA: 0s - loss: 1.0524 - accuracy: 0.6231
# Epoch 21: val_loss did not improve from 1.17700
# 98/98 [==============================] - 2s 16ms/step - loss: 1.0520 - accuracy: 0.6232 - val_loss: 1.2010 - val_accuracy: 0.5636 - lr: 5.4000e-05
# Epoch 22/226
# 95/98 [============================>.] - ETA: 0s - loss: 1.0366 - accuracy: 0.6243
# Epoch 22: val_loss did not improve from 1.17700
# 98/98 [==============================] - 2s 16ms/step - loss: 1.0366 - accuracy: 0.6240 - val_loss: 1.1941 - val_accuracy: 0.5788 - lr: 5.4000e-05
# Epoch 23/226
# 95/98 [============================>.] - ETA: 0s - loss: 1.0340 - accuracy: 0.6299
# Epoch 23: val_loss improved from 1.17700 to 1.17239, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 17ms/step - loss: 1.0338 - accuracy: 0.6299 - val_loss: 1.1724 - val_accuracy: 0.5669 - lr: 5.4000e-05
# Epoch 24/226
# 97/98 [============================>.] - ETA: 0s - loss: 1.0186 - accuracy: 0.6339
# Epoch 24: val_loss improved from 1.17239 to 1.15411, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 17ms/step - loss: 1.0189 - accuracy: 0.6338 - val_loss: 1.1541 - val_accuracy: 0.5831 - lr: 5.4000e-05
# Epoch 25/226
# 96/98 [============================>.] - ETA: 0s - loss: 1.0168 - accuracy: 0.6352
# Epoch 25: val_loss improved from 1.15411 to 1.15289, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 17ms/step - loss: 1.0172 - accuracy: 0.6351 - val_loss: 1.1529 - val_accuracy: 0.5831 - lr: 5.4000e-05
# Epoch 26/226
# 95/98 [============================>.] - ETA: 0s - loss: 1.0093 - accuracy: 0.6331
# Epoch 26: val_loss did not improve from 1.15289
# 98/98 [==============================] - 2s 17ms/step - loss: 1.0097 - accuracy: 0.6331 - val_loss: 1.1605 - val_accuracy: 0.5788 - lr: 5.4000e-05
# Epoch 27/226
# 95/98 [============================>.] - ETA: 0s - loss: 1.0048 - accuracy: 0.6401
# Epoch 27: val_loss did not improve from 1.15289
# 98/98 [==============================] - 2s 18ms/step - loss: 1.0045 - accuracy: 0.6404 - val_loss: 1.1563 - val_accuracy: 0.5729 - lr: 5.4000e-05
# Epoch 28/226
# 98/98 [==============================] - ETA: 0s - loss: 0.9987 - accuracy: 0.6409
# Epoch 28: val_loss improved from 1.15289 to 1.12803, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 18ms/step - loss: 0.9987 - accuracy: 0.6409 - val_loss: 1.1280 - val_accuracy: 0.5890 - lr: 5.4000e-05
# Epoch 29/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.9885 - accuracy: 0.6428
# Epoch 29: val_loss did not improve from 1.12803
# 98/98 [==============================] - 2s 17ms/step - loss: 0.9879 - accuracy: 0.6432 - val_loss: 1.1291 - val_accuracy: 0.5898 - lr: 5.4000e-05
# Epoch 30/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.9777 - accuracy: 0.6469
# Epoch 30: val_loss did not improve from 1.12803
# 98/98 [==============================] - 2s 17ms/step - loss: 0.9777 - accuracy: 0.6467 - val_loss: 1.1346 - val_accuracy: 0.5805 - lr: 5.4000e-05
# Epoch 31/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.9724 - accuracy: 0.6488
# Epoch 31: val_loss improved from 1.12803 to 1.11974, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 18ms/step - loss: 0.9738 - accuracy: 0.6487 - val_loss: 1.1197 - val_accuracy: 0.5898 - lr: 5.4000e-05
# Epoch 32/226
# 95/98 [============================>.] - ETA: 0s - loss: 0.9693 - accuracy: 0.6502
# Epoch 32: val_loss did not improve from 1.11974
# 98/98 [==============================] - 2s 17ms/step - loss: 0.9692 - accuracy: 0.6502 - val_loss: 1.1510 - val_accuracy: 0.5686 - lr: 5.4000e-05
# Epoch 33/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.9581 - accuracy: 0.6550
# Epoch 33: val_loss did not improve from 1.11974
# 98/98 [==============================] - 2s 17ms/step - loss: 0.9582 - accuracy: 0.6550 - val_loss: 1.1278 - val_accuracy: 0.5958 - lr: 5.4000e-05
# Epoch 34/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.9533 - accuracy: 0.6517
# Epoch 34: val_loss did not improve from 1.11974
# 98/98 [==============================] - 3s 28ms/step - loss: 0.9534 - accuracy: 0.6516 - val_loss: 1.1407 - val_accuracy: 0.5839 - lr: 5.4000e-05
# Epoch 35/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.9518 - accuracy: 0.6581
# Epoch 35: val_loss did not improve from 1.11974
# 98/98 [==============================] - 2s 24ms/step - loss: 0.9519 - accuracy: 0.6582 - val_loss: 1.1279 - val_accuracy: 0.5720 - lr: 5.4000e-05
# Epoch 36/226
# 98/98 [==============================] - ETA: 0s - loss: 0.9441 - accuracy: 0.6587
# Epoch 36: val_loss improved from 1.11974 to 1.09559, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 23ms/step - loss: 0.9441 - accuracy: 0.6587 - val_loss: 1.0956 - val_accuracy: 0.5966 - lr: 5.4000e-05
# Epoch 37/226
# 95/98 [============================>.] - ETA: 0s - loss: 0.9392 - accuracy: 0.6627
# Epoch 37: val_loss did not improve from 1.09559
# 98/98 [==============================] - 2s 17ms/step - loss: 0.9396 - accuracy: 0.6618 - val_loss: 1.1012 - val_accuracy: 0.5890 - lr: 5.4000e-05
# Epoch 38/226
# 98/98 [==============================] - ETA: 0s - loss: 0.9345 - accuracy: 0.6593
# Epoch 38: val_loss did not improve from 1.09559
# 98/98 [==============================] - 2s 16ms/step - loss: 0.9345 - accuracy: 0.6593 - val_loss: 1.1110 - val_accuracy: 0.5805 - lr: 5.4000e-05
# Epoch 39/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.9264 - accuracy: 0.6629
# Epoch 39: val_loss did not improve from 1.09559
# 98/98 [==============================] - 2s 17ms/step - loss: 0.9267 - accuracy: 0.6628 - val_loss: 1.1022 - val_accuracy: 0.5873 - lr: 5.4000e-05
# Epoch 40/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.9240 - accuracy: 0.6638
# Epoch 40: val_loss improved from 1.09559 to 1.09094, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 22ms/step - loss: 0.9222 - accuracy: 0.6647 - val_loss: 1.0909 - val_accuracy: 0.5881 - lr: 5.4000e-05
# Epoch 41/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.9199 - accuracy: 0.6665
# Epoch 41: val_loss improved from 1.09094 to 1.07950, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 19ms/step - loss: 0.9200 - accuracy: 0.6664 - val_loss: 1.0795 - val_accuracy: 0.6000 - lr: 4.8600e-05
# Epoch 42/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.9169 - accuracy: 0.6668
# Epoch 42: val_loss did not improve from 1.07950
# 98/98 [==============================] - 2s 18ms/step - loss: 0.9163 - accuracy: 0.6671 - val_loss: 1.0864 - val_accuracy: 0.5932 - lr: 4.8600e-05
# Epoch 43/226
# 98/98 [==============================] - ETA: 0s - loss: 0.9059 - accuracy: 0.6725
# Epoch 43: val_loss improved from 1.07950 to 1.07727, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 17ms/step - loss: 0.9059 - accuracy: 0.6725 - val_loss: 1.0773 - val_accuracy: 0.5958 - lr: 4.8600e-05
# Epoch 44/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.9024 - accuracy: 0.6710
# Epoch 44: val_loss did not improve from 1.07727
# 98/98 [==============================] - 2s 16ms/step - loss: 0.9023 - accuracy: 0.6711 - val_loss: 1.0856 - val_accuracy: 0.6008 - lr: 4.8600e-05
# Epoch 45/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.9035 - accuracy: 0.6698
# Epoch 45: val_loss improved from 1.07727 to 1.07428, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 17ms/step - loss: 0.9043 - accuracy: 0.6693 - val_loss: 1.0743 - val_accuracy: 0.5992 - lr: 4.8600e-05
# Epoch 46/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.8970 - accuracy: 0.6743
# Epoch 46: val_loss did not improve from 1.07428
# 98/98 [==============================] - 2s 17ms/step - loss: 0.8974 - accuracy: 0.6739 - val_loss: 1.0826 - val_accuracy: 0.6034 - lr: 4.8600e-05
# Epoch 47/226
# 95/98 [============================>.] - ETA: 0s - loss: 0.8915 - accuracy: 0.6729
# Epoch 47: val_loss improved from 1.07428 to 1.06763, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 17ms/step - loss: 0.8906 - accuracy: 0.6733 - val_loss: 1.0676 - val_accuracy: 0.5992 - lr: 4.8600e-05
# Epoch 48/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.8870 - accuracy: 0.6767
# Epoch 48: val_loss did not improve from 1.06763
# 98/98 [==============================] - 2s 17ms/step - loss: 0.8872 - accuracy: 0.6768 - val_loss: 1.0760 - val_accuracy: 0.5898 - lr: 4.8600e-05
# Epoch 49/226
# 95/98 [============================>.] - ETA: 0s - loss: 0.8822 - accuracy: 0.6785
# Epoch 49: val_loss did not improve from 1.06763
# 98/98 [==============================] - 2s 19ms/step - loss: 0.8828 - accuracy: 0.6777 - val_loss: 1.0741 - val_accuracy: 0.6034 - lr: 4.8600e-05
# Epoch 50/226
# 98/98 [==============================] - ETA: 0s - loss: 0.8830 - accuracy: 0.6793
# Epoch 50: val_loss improved from 1.06763 to 1.05363, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 18ms/step - loss: 0.8830 - accuracy: 0.6793 - val_loss: 1.0536 - val_accuracy: 0.5932 - lr: 4.8600e-05
# Epoch 51/226
# 95/98 [============================>.] - ETA: 0s - loss: 0.8811 - accuracy: 0.6791
# Epoch 51: val_loss did not improve from 1.05363
# 98/98 [==============================] - 2s 16ms/step - loss: 0.8795 - accuracy: 0.6793 - val_loss: 1.0629 - val_accuracy: 0.5941 - lr: 4.8600e-05
# Epoch 52/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.8716 - accuracy: 0.6823
# Epoch 52: val_loss did not improve from 1.05363
# 98/98 [==============================] - 2s 17ms/step - loss: 0.8716 - accuracy: 0.6822 - val_loss: 1.0694 - val_accuracy: 0.5949 - lr: 4.8600e-05
# Epoch 53/226
# 98/98 [==============================] - ETA: 0s - loss: 0.8676 - accuracy: 0.6875
# Epoch 53: val_loss improved from 1.05363 to 1.05108, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 17ms/step - loss: 0.8676 - accuracy: 0.6875 - val_loss: 1.0511 - val_accuracy: 0.5983 - lr: 4.8600e-05
# Epoch 54/226
# 95/98 [============================>.] - ETA: 0s - loss: 0.8696 - accuracy: 0.6828
# Epoch 54: val_loss did not improve from 1.05108
# 98/98 [==============================] - 2s 16ms/step - loss: 0.8682 - accuracy: 0.6835 - val_loss: 1.0541 - val_accuracy: 0.6076 - lr: 4.8600e-05
# Epoch 55/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.8627 - accuracy: 0.6860
# Epoch 55: val_loss did not improve from 1.05108
# 98/98 [==============================] - 2s 16ms/step - loss: 0.8632 - accuracy: 0.6859 - val_loss: 1.0526 - val_accuracy: 0.5975 - lr: 4.8600e-05
# Epoch 56/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.8579 - accuracy: 0.6873
# Epoch 56: val_loss did not improve from 1.05108
# 98/98 [==============================] - 2s 18ms/step - loss: 0.8579 - accuracy: 0.6875 - val_loss: 1.0630 - val_accuracy: 0.5958 - lr: 4.8600e-05
# Epoch 57/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.8599 - accuracy: 0.6865
# Epoch 57: val_loss did not improve from 1.05108
# 98/98 [==============================] - 2s 18ms/step - loss: 0.8602 - accuracy: 0.6866 - val_loss: 1.0623 - val_accuracy: 0.6025 - lr: 4.8600e-05
# Epoch 58/226
# 95/98 [============================>.] - ETA: 0s - loss: 0.8530 - accuracy: 0.6912
# Epoch 58: val_loss improved from 1.05108 to 1.04358, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 17ms/step - loss: 0.8542 - accuracy: 0.6907 - val_loss: 1.0436 - val_accuracy: 0.6059 - lr: 4.8600e-05
# Epoch 59/226
# 95/98 [============================>.] - ETA: 0s - loss: 0.8564 - accuracy: 0.6890
# Epoch 59: val_loss did not improve from 1.04358
# 98/98 [==============================] - 2s 16ms/step - loss: 0.8559 - accuracy: 0.6893 - val_loss: 1.0566 - val_accuracy: 0.6000 - lr: 4.8600e-05
# Epoch 60/226
# 95/98 [============================>.] - ETA: 0s - loss: 0.8485 - accuracy: 0.6901
# Epoch 60: val_loss improved from 1.04358 to 1.03994, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 17ms/step - loss: 0.8478 - accuracy: 0.6905 - val_loss: 1.0399 - val_accuracy: 0.6051 - lr: 4.8600e-05
# Epoch 61/226
# 95/98 [============================>.] - ETA: 0s - loss: 0.8427 - accuracy: 0.6934
# Epoch 61: val_loss did not improve from 1.03994
# 98/98 [==============================] - 2s 17ms/step - loss: 0.8424 - accuracy: 0.6936 - val_loss: 1.0564 - val_accuracy: 0.6008 - lr: 4.3740e-05
# Epoch 62/226
# 95/98 [============================>.] - ETA: 0s - loss: 0.8423 - accuracy: 0.6929
# Epoch 62: val_loss improved from 1.03994 to 1.03454, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 17ms/step - loss: 0.8428 - accuracy: 0.6927 - val_loss: 1.0345 - val_accuracy: 0.6136 - lr: 4.3740e-05
# Epoch 63/226
# 98/98 [==============================] - ETA: 0s - loss: 0.8355 - accuracy: 0.6957
# Epoch 63: val_loss did not improve from 1.03454
# 98/98 [==============================] - 2s 17ms/step - loss: 0.8355 - accuracy: 0.6957 - val_loss: 1.0391 - val_accuracy: 0.6102 - lr: 4.3740e-05
# Epoch 64/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.8296 - accuracy: 0.6987
# Epoch 64: val_loss improved from 1.03454 to 1.03286, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 19ms/step - loss: 0.8304 - accuracy: 0.6984 - val_loss: 1.0329 - val_accuracy: 0.6136 - lr: 4.3740e-05
# Epoch 65/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.8318 - accuracy: 0.6963
# Epoch 65: val_loss improved from 1.03286 to 1.03194, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 19ms/step - loss: 0.8320 - accuracy: 0.6963 - val_loss: 1.0319 - val_accuracy: 0.6110 - lr: 4.3740e-05
# Epoch 66/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.8289 - accuracy: 0.6995
# Epoch 66: val_loss did not improve from 1.03194
# 98/98 [==============================] - 2s 16ms/step - loss: 0.8292 - accuracy: 0.6995 - val_loss: 1.0362 - val_accuracy: 0.6025 - lr: 4.3740e-05
# Epoch 67/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.8245 - accuracy: 0.6983
# Epoch 67: val_loss did not improve from 1.03194
# 98/98 [==============================] - 2s 17ms/step - loss: 0.8241 - accuracy: 0.6984 - val_loss: 1.0331 - val_accuracy: 0.6085 - lr: 4.3740e-05
# Epoch 68/226
# 98/98 [==============================] - ETA: 0s - loss: 0.8243 - accuracy: 0.6991
# Epoch 68: val_loss did not improve from 1.03194
# 98/98 [==============================] - 2s 16ms/step - loss: 0.8243 - accuracy: 0.6991 - val_loss: 1.0340 - val_accuracy: 0.6051 - lr: 4.3740e-05
# Epoch 69/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.8233 - accuracy: 0.7017
# Epoch 69: val_loss did not improve from 1.03194
# 98/98 [==============================] - 2s 16ms/step - loss: 0.8232 - accuracy: 0.7018 - val_loss: 1.0375 - val_accuracy: 0.6042 - lr: 4.3740e-05
# Epoch 70/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.8145 - accuracy: 0.7019
# Epoch 70: val_loss did not improve from 1.03194
# 98/98 [==============================] - 2s 17ms/step - loss: 0.8148 - accuracy: 0.7017 - val_loss: 1.0356 - val_accuracy: 0.6042 - lr: 4.3740e-05
# Epoch 71/226
# 95/98 [============================>.] - ETA: 0s - loss: 0.8155 - accuracy: 0.7021
# Epoch 71: val_loss improved from 1.03194 to 1.01675, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 23ms/step - loss: 0.8143 - accuracy: 0.7024 - val_loss: 1.0168 - val_accuracy: 0.6102 - lr: 4.3740e-05
# Epoch 72/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.8142 - accuracy: 0.7042
# Epoch 72: val_loss did not improve from 1.01675
# 98/98 [==============================] - 2s 19ms/step - loss: 0.8137 - accuracy: 0.7043 - val_loss: 1.0305 - val_accuracy: 0.6102 - lr: 4.3740e-05
# Epoch 73/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.8102 - accuracy: 0.7041
# Epoch 73: val_loss did not improve from 1.01675
# 98/98 [==============================] - 2s 17ms/step - loss: 0.8103 - accuracy: 0.7040 - val_loss: 1.0240 - val_accuracy: 0.6119 - lr: 4.3740e-05
# Epoch 74/226
# 95/98 [============================>.] - ETA: 0s - loss: 0.8067 - accuracy: 0.7075
# Epoch 74: val_loss improved from 1.01675 to 1.01590, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 17ms/step - loss: 0.8060 - accuracy: 0.7077 - val_loss: 1.0159 - val_accuracy: 0.6153 - lr: 4.3740e-05
# Epoch 75/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.8073 - accuracy: 0.7071
# Epoch 75: val_loss did not improve from 1.01590
# 98/98 [==============================] - 2s 16ms/step - loss: 0.8069 - accuracy: 0.7073 - val_loss: 1.0252 - val_accuracy: 0.6085 - lr: 4.3740e-05
# Epoch 76/226
# 95/98 [============================>.] - ETA: 0s - loss: 0.8042 - accuracy: 0.7044
# Epoch 76: val_loss did not improve from 1.01590
# 98/98 [==============================] - 2s 16ms/step - loss: 0.8042 - accuracy: 0.7045 - val_loss: 1.0185 - val_accuracy: 0.6042 - lr: 4.3740e-05
# Epoch 77/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.8022 - accuracy: 0.7071
# Epoch 77: val_loss improved from 1.01590 to 1.01354, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 17ms/step - loss: 0.8022 - accuracy: 0.7072 - val_loss: 1.0135 - val_accuracy: 0.6161 - lr: 4.3740e-05
# Epoch 78/226
# 95/98 [============================>.] - ETA: 0s - loss: 0.8023 - accuracy: 0.7028
# Epoch 78: val_loss did not improve from 1.01354
# 98/98 [==============================] - 2s 16ms/step - loss: 0.8008 - accuracy: 0.7033 - val_loss: 1.0208 - val_accuracy: 0.6102 - lr: 4.3740e-05
# Epoch 79/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.7987 - accuracy: 0.7090
# Epoch 79: val_loss did not improve from 1.01354
# 98/98 [==============================] - 2s 18ms/step - loss: 0.7985 - accuracy: 0.7091 - val_loss: 1.0204 - val_accuracy: 0.6212 - lr: 4.3740e-05
# Epoch 80/226
# 95/98 [============================>.] - ETA: 0s - loss: 0.7914 - accuracy: 0.7104
# Epoch 80: val_loss improved from 1.01354 to 0.99901, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 19ms/step - loss: 0.7915 - accuracy: 0.7100 - val_loss: 0.9990 - val_accuracy: 0.6203 - lr: 4.3740e-05
# Epoch 81/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.7911 - accuracy: 0.7119
# Epoch 81: val_loss did not improve from 0.99901
# 98/98 [==============================] - 2s 17ms/step - loss: 0.7909 - accuracy: 0.7122 - val_loss: 1.0059 - val_accuracy: 0.6195 - lr: 3.9366e-05
# Epoch 82/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.7886 - accuracy: 0.7109
# Epoch 82: val_loss did not improve from 0.99901
# 98/98 [==============================] - 2s 16ms/step - loss: 0.7882 - accuracy: 0.7110 - val_loss: 1.0046 - val_accuracy: 0.6093 - lr: 3.9366e-05
# Epoch 83/226
# 95/98 [============================>.] - ETA: 0s - loss: 0.7813 - accuracy: 0.7155
# Epoch 83: val_loss did not improve from 0.99901
# 98/98 [==============================] - 2s 16ms/step - loss: 0.7821 - accuracy: 0.7153 - val_loss: 1.0173 - val_accuracy: 0.6178 - lr: 3.9366e-05
# Epoch 84/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.7822 - accuracy: 0.7147
# Epoch 84: val_loss improved from 0.99901 to 0.99328, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 23ms/step - loss: 0.7823 - accuracy: 0.7148 - val_loss: 0.9933 - val_accuracy: 0.6246 - lr: 3.9366e-05
# Epoch 85/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.7867 - accuracy: 0.7147
# Epoch 85: val_loss did not improve from 0.99328
# 98/98 [==============================] - 2s 16ms/step - loss: 0.7852 - accuracy: 0.7153 - val_loss: 1.0024 - val_accuracy: 0.6119 - lr: 3.9366e-05
# Epoch 86/226
# 95/98 [============================>.] - ETA: 0s - loss: 0.7819 - accuracy: 0.7137
# Epoch 86: val_loss did not improve from 0.99328
# 98/98 [==============================] - 2s 17ms/step - loss: 0.7827 - accuracy: 0.7134 - val_loss: 1.0051 - val_accuracy: 0.6237 - lr: 3.9366e-05
# Epoch 87/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.7761 - accuracy: 0.7166
# Epoch 87: val_loss did not improve from 0.99328
# 98/98 [==============================] - 2s 19ms/step - loss: 0.7765 - accuracy: 0.7165 - val_loss: 1.0052 - val_accuracy: 0.6144 - lr: 3.9366e-05
# Epoch 88/226
# 98/98 [==============================] - ETA: 0s - loss: 0.7772 - accuracy: 0.7144
# Epoch 88: val_loss did not improve from 0.99328
# 98/98 [==============================] - 2s 18ms/step - loss: 0.7772 - accuracy: 0.7144 - val_loss: 0.9936 - val_accuracy: 0.6237 - lr: 3.9366e-05
# Epoch 89/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.7772 - accuracy: 0.7182
# Epoch 89: val_loss improved from 0.99328 to 0.99328, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 22ms/step - loss: 0.7773 - accuracy: 0.7183 - val_loss: 0.9933 - val_accuracy: 0.6237 - lr: 3.9366e-05
# Epoch 90/226
# 98/98 [==============================] - ETA: 0s - loss: 0.7741 - accuracy: 0.7164
# Epoch 90: val_loss did not improve from 0.99328
# 98/98 [==============================] - 2s 16ms/step - loss: 0.7741 - accuracy: 0.7164 - val_loss: 1.0166 - val_accuracy: 0.6169 - lr: 3.9366e-05
# Epoch 91/226
# 95/98 [============================>.] - ETA: 0s - loss: 0.7670 - accuracy: 0.7186
# Epoch 91: val_loss did not improve from 0.99328
# 98/98 [==============================] - 2s 16ms/step - loss: 0.7668 - accuracy: 0.7186 - val_loss: 1.0023 - val_accuracy: 0.6195 - lr: 3.9366e-05
# Epoch 92/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.7742 - accuracy: 0.7177
# Epoch 92: val_loss did not improve from 0.99328
# 98/98 [==============================] - 2s 16ms/step - loss: 0.7744 - accuracy: 0.7175 - val_loss: 1.0325 - val_accuracy: 0.6025 - lr: 3.9366e-05
# Epoch 93/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.7699 - accuracy: 0.7203
# Epoch 93: val_loss improved from 0.99328 to 0.99280, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 24ms/step - loss: 0.7703 - accuracy: 0.7202 - val_loss: 0.9928 - val_accuracy: 0.6229 - lr: 3.9366e-05
# Epoch 94/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.7618 - accuracy: 0.7216
# Epoch 94: val_loss improved from 0.99280 to 0.99026, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 20ms/step - loss: 0.7631 - accuracy: 0.7210 - val_loss: 0.9903 - val_accuracy: 0.6153 - lr: 3.9366e-05
# Epoch 95/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.7654 - accuracy: 0.7213
# Epoch 95: val_loss did not improve from 0.99026
# 98/98 [==============================] - 2s 17ms/step - loss: 0.7655 - accuracy: 0.7212 - val_loss: 0.9974 - val_accuracy: 0.6144 - lr: 3.9366e-05
# Epoch 96/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.7590 - accuracy: 0.7211
# Epoch 96: val_loss did not improve from 0.99026
# 98/98 [==============================] - 2s 17ms/step - loss: 0.7593 - accuracy: 0.7208 - val_loss: 0.9927 - val_accuracy: 0.6212 - lr: 3.9366e-05
# Epoch 97/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.7661 - accuracy: 0.7209
# Epoch 97: val_loss did not improve from 0.99026
# 98/98 [==============================] - 2s 16ms/step - loss: 0.7662 - accuracy: 0.7208 - val_loss: 1.0002 - val_accuracy: 0.6254 - lr: 3.9366e-05
# Epoch 98/226
# 98/98 [==============================] - ETA: 0s - loss: 0.7648 - accuracy: 0.7208
# Epoch 98: val_loss did not improve from 0.99026
# 98/98 [==============================] - 2s 16ms/step - loss: 0.7648 - accuracy: 0.7208 - val_loss: 0.9941 - val_accuracy: 0.6263 - lr: 3.9366e-05
# Epoch 99/226
# 98/98 [==============================] - ETA: 0s - loss: 0.7597 - accuracy: 0.7221
# Epoch 99: val_loss did not improve from 0.99026
# 98/98 [==============================] - 2s 16ms/step - loss: 0.7597 - accuracy: 0.7221 - val_loss: 0.9971 - val_accuracy: 0.6212 - lr: 3.9366e-05
# Epoch 100/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.7546 - accuracy: 0.7239
# Epoch 100: val_loss did not improve from 0.99026
# 98/98 [==============================] - 2s 17ms/step - loss: 0.7551 - accuracy: 0.7238 - val_loss: 0.9984 - val_accuracy: 0.6263 - lr: 3.9366e-05
# Epoch 101/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.7578 - accuracy: 0.7218
# Epoch 101: val_loss did not improve from 0.99026
# 98/98 [==============================] - 2s 17ms/step - loss: 0.7577 - accuracy: 0.7219 - val_loss: 1.0007 - val_accuracy: 0.6220 - lr: 3.5429e-05
# Epoch 102/226
# 95/98 [============================>.] - ETA: 0s - loss: 0.7559 - accuracy: 0.7210
# Epoch 102: val_loss did not improve from 0.99026
# 98/98 [==============================] - 2s 18ms/step - loss: 0.7561 - accuracy: 0.7211 - val_loss: 0.9909 - val_accuracy: 0.6203 - lr: 3.5429e-05
# Epoch 103/226
# 98/98 [==============================] - ETA: 0s - loss: 0.7491 - accuracy: 0.7275
# Epoch 103: val_loss did not improve from 0.99026
# 98/98 [==============================] - 2s 17ms/step - loss: 0.7491 - accuracy: 0.7275 - val_loss: 1.0040 - val_accuracy: 0.6161 - lr: 3.5429e-05
# Epoch 104/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.7434 - accuracy: 0.7257
# Epoch 104: val_loss did not improve from 0.99026
# 98/98 [==============================] - 2s 17ms/step - loss: 0.7433 - accuracy: 0.7259 - val_loss: 0.9939 - val_accuracy: 0.6178 - lr: 3.5429e-05
# Epoch 105/226
# 98/98 [==============================] - ETA: 0s - loss: 0.7497 - accuracy: 0.7235
# Epoch 105: val_loss did not improve from 0.99026
# 98/98 [==============================] - 2s 17ms/step - loss: 0.7497 - accuracy: 0.7235 - val_loss: 0.9960 - val_accuracy: 0.6127 - lr: 3.5429e-05
# Epoch 106/226
# 98/98 [==============================] - ETA: 0s - loss: 0.7420 - accuracy: 0.7275
# Epoch 106: val_loss improved from 0.99026 to 0.97855, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 25ms/step - loss: 0.7420 - accuracy: 0.7275 - val_loss: 0.9786 - val_accuracy: 0.6305 - lr: 3.5429e-05
# Epoch 107/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.7451 - accuracy: 0.7285
# Epoch 107: val_loss improved from 0.97855 to 0.97757, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 17ms/step - loss: 0.7449 - accuracy: 0.7287 - val_loss: 0.9776 - val_accuracy: 0.6263 - lr: 3.5429e-05
# Epoch 108/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.7421 - accuracy: 0.7278
# Epoch 108: val_loss did not improve from 0.97757
# 98/98 [==============================] - 2s 16ms/step - loss: 0.7432 - accuracy: 0.7275 - val_loss: 1.0041 - val_accuracy: 0.6186 - lr: 3.5429e-05
# Epoch 109/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.7423 - accuracy: 0.7264
# Epoch 109: val_loss improved from 0.97757 to 0.97535, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 19ms/step - loss: 0.7417 - accuracy: 0.7265 - val_loss: 0.9753 - val_accuracy: 0.6203 - lr: 3.5429e-05
# Epoch 110/226
# 95/98 [============================>.] - ETA: 0s - loss: 0.7392 - accuracy: 0.7289
# Epoch 110: val_loss did not improve from 0.97535
# 98/98 [==============================] - 2s 18ms/step - loss: 0.7384 - accuracy: 0.7290 - val_loss: 0.9855 - val_accuracy: 0.6288 - lr: 3.5429e-05
# Epoch 111/226
# 95/98 [============================>.] - ETA: 0s - loss: 0.7403 - accuracy: 0.7309
# Epoch 111: val_loss did not improve from 0.97535
# 98/98 [==============================] - 2s 17ms/step - loss: 0.7390 - accuracy: 0.7314 - val_loss: 0.9969 - val_accuracy: 0.6186 - lr: 3.5429e-05
# Epoch 112/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.7364 - accuracy: 0.7304
# Epoch 112: val_loss did not improve from 0.97535
# 98/98 [==============================] - 2s 17ms/step - loss: 0.7366 - accuracy: 0.7304 - val_loss: 0.9927 - val_accuracy: 0.6119 - lr: 3.5429e-05
# Epoch 113/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.7342 - accuracy: 0.7308
# Epoch 113: val_loss improved from 0.97535 to 0.97307, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 18ms/step - loss: 0.7341 - accuracy: 0.7308 - val_loss: 0.9731 - val_accuracy: 0.6229 - lr: 3.5429e-05
# Epoch 114/226
# 98/98 [==============================] - ETA: 0s - loss: 0.7348 - accuracy: 0.7320
# Epoch 114: val_loss improved from 0.97307 to 0.97077, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 17ms/step - loss: 0.7348 - accuracy: 0.7320 - val_loss: 0.9708 - val_accuracy: 0.6246 - lr: 3.5429e-05
# Epoch 115/226
# 98/98 [==============================] - ETA: 0s - loss: 0.7313 - accuracy: 0.7311
# Epoch 115: val_loss did not improve from 0.97077
# 98/98 [==============================] - 2s 17ms/step - loss: 0.7313 - accuracy: 0.7311 - val_loss: 0.9803 - val_accuracy: 0.6186 - lr: 3.5429e-05
# Epoch 116/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.7274 - accuracy: 0.7328
# Epoch 116: val_loss did not improve from 0.97077
# 98/98 [==============================] - 2s 17ms/step - loss: 0.7278 - accuracy: 0.7326 - val_loss: 0.9748 - val_accuracy: 0.6280 - lr: 3.5429e-05
# Epoch 117/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.7317 - accuracy: 0.7316
# Epoch 117: val_loss did not improve from 0.97077
# 98/98 [==============================] - 2s 19ms/step - loss: 0.7312 - accuracy: 0.7320 - val_loss: 0.9802 - val_accuracy: 0.6271 - lr: 3.5429e-05
# Epoch 118/226
# 95/98 [============================>.] - ETA: 0s - loss: 0.7252 - accuracy: 0.7326
# Epoch 118: val_loss did not improve from 0.97077
# 98/98 [==============================] - 2s 18ms/step - loss: 0.7247 - accuracy: 0.7331 - val_loss: 0.9768 - val_accuracy: 0.6178 - lr: 3.5429e-05
# Epoch 119/226
# 95/98 [============================>.] - ETA: 0s - loss: 0.7250 - accuracy: 0.7322
# Epoch 119: val_loss did not improve from 0.97077
# 98/98 [==============================] - 2s 17ms/step - loss: 0.7238 - accuracy: 0.7328 - val_loss: 0.9814 - val_accuracy: 0.6220 - lr: 3.5429e-05
# Epoch 120/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.7279 - accuracy: 0.7337
# Epoch 120: val_loss did not improve from 0.97077
# 98/98 [==============================] - 2s 17ms/step - loss: 0.7279 - accuracy: 0.7337 - val_loss: 0.9737 - val_accuracy: 0.6288 - lr: 3.5429e-05
# Epoch 121/226
# 98/98 [==============================] - ETA: 0s - loss: 0.7224 - accuracy: 0.7337
# Epoch 121: val_loss did not improve from 0.97077
# 98/98 [==============================] - 2s 17ms/step - loss: 0.7224 - accuracy: 0.7337 - val_loss: 0.9719 - val_accuracy: 0.6297 - lr: 3.1886e-05
# Epoch 122/226
# 95/98 [============================>.] - ETA: 0s - loss: 0.7198 - accuracy: 0.7362
# Epoch 122: val_loss did not improve from 0.97077
# 98/98 [==============================] - 2s 17ms/step - loss: 0.7203 - accuracy: 0.7361 - val_loss: 0.9785 - val_accuracy: 0.6280 - lr: 3.1886e-05
# Epoch 123/226
# 98/98 [==============================] - ETA: 0s - loss: 0.7228 - accuracy: 0.7360
# Epoch 123: val_loss did not improve from 0.97077
# 98/98 [==============================] - 2s 17ms/step - loss: 0.7228 - accuracy: 0.7360 - val_loss: 0.9837 - val_accuracy: 0.6237 - lr: 3.1886e-05
# Epoch 124/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.7138 - accuracy: 0.7361
# Epoch 124: val_loss improved from 0.97077 to 0.96838, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 23ms/step - loss: 0.7142 - accuracy: 0.7358 - val_loss: 0.9684 - val_accuracy: 0.6280 - lr: 3.1886e-05
# Epoch 125/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.7142 - accuracy: 0.7355
# Epoch 125: val_loss did not improve from 0.96838
# 98/98 [==============================] - 2s 19ms/step - loss: 0.7141 - accuracy: 0.7356 - val_loss: 0.9817 - val_accuracy: 0.6186 - lr: 3.1886e-05
# Epoch 126/226
# 98/98 [==============================] - ETA: 0s - loss: 0.7149 - accuracy: 0.7344
# Epoch 126: val_loss did not improve from 0.96838
# 98/98 [==============================] - 2s 16ms/step - loss: 0.7149 - accuracy: 0.7344 - val_loss: 0.9705 - val_accuracy: 0.6229 - lr: 3.1886e-05
# Epoch 127/226
# 95/98 [============================>.] - ETA: 0s - loss: 0.7162 - accuracy: 0.7383
# Epoch 127: val_loss improved from 0.96838 to 0.96719, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 17ms/step - loss: 0.7161 - accuracy: 0.7383 - val_loss: 0.9672 - val_accuracy: 0.6288 - lr: 3.1886e-05
# Epoch 128/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.7114 - accuracy: 0.7370
# Epoch 128: val_loss did not improve from 0.96719
# 98/98 [==============================] - 2s 16ms/step - loss: 0.7110 - accuracy: 0.7372 - val_loss: 0.9828 - val_accuracy: 0.6254 - lr: 3.1886e-05
# Epoch 129/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.7132 - accuracy: 0.7369
# Epoch 129: val_loss did not improve from 0.96719
# 98/98 [==============================] - 2s 16ms/step - loss: 0.7135 - accuracy: 0.7369 - val_loss: 0.9795 - val_accuracy: 0.6229 - lr: 3.1886e-05
# Epoch 130/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.7145 - accuracy: 0.7378
# Epoch 130: val_loss improved from 0.96719 to 0.95332, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 17ms/step - loss: 0.7146 - accuracy: 0.7378 - val_loss: 0.9533 - val_accuracy: 0.6364 - lr: 3.1886e-05
# Epoch 131/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.7102 - accuracy: 0.7413
# Epoch 131: val_loss did not improve from 0.95332
# 98/98 [==============================] - 2s 16ms/step - loss: 0.7106 - accuracy: 0.7410 - val_loss: 0.9639 - val_accuracy: 0.6288 - lr: 3.1886e-05
# Epoch 132/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.7080 - accuracy: 0.7410
# Epoch 132: val_loss did not improve from 0.95332
# 98/98 [==============================] - 2s 18ms/step - loss: 0.7076 - accuracy: 0.7410 - val_loss: 0.9877 - val_accuracy: 0.6220 - lr: 3.1886e-05
# Epoch 133/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.7122 - accuracy: 0.7354
# Epoch 133: val_loss did not improve from 0.95332
# 98/98 [==============================] - 2s 18ms/step - loss: 0.7127 - accuracy: 0.7352 - val_loss: 0.9698 - val_accuracy: 0.6271 - lr: 3.1886e-05
# Epoch 134/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.7090 - accuracy: 0.7393
# Epoch 134: val_loss did not improve from 0.95332
# 98/98 [==============================] - 2s 16ms/step - loss: 0.7086 - accuracy: 0.7395 - val_loss: 0.9656 - val_accuracy: 0.6254 - lr: 3.1886e-05
# Epoch 135/226
# 95/98 [============================>.] - ETA: 0s - loss: 0.7104 - accuracy: 0.7399
# Epoch 135: val_loss did not improve from 0.95332
# 98/98 [==============================] - 2s 16ms/step - loss: 0.7091 - accuracy: 0.7401 - val_loss: 0.9822 - val_accuracy: 0.6169 - lr: 3.1886e-05
# Epoch 136/226
# 98/98 [==============================] - ETA: 0s - loss: 0.7096 - accuracy: 0.7388
# Epoch 136: val_loss did not improve from 0.95332
# 98/98 [==============================] - 2s 16ms/step - loss: 0.7096 - accuracy: 0.7388 - val_loss: 0.9725 - val_accuracy: 0.6186 - lr: 3.1886e-05
# Epoch 137/226
# 98/98 [==============================] - ETA: 0s - loss: 0.7017 - accuracy: 0.7426
# Epoch 137: val_loss did not improve from 0.95332
# 98/98 [==============================] - 2s 16ms/step - loss: 0.7017 - accuracy: 0.7426 - val_loss: 0.9784 - val_accuracy: 0.6246 - lr: 3.1886e-05
# Epoch 138/226
# 98/98 [==============================] - ETA: 0s - loss: 0.7034 - accuracy: 0.7400
# Epoch 138: val_loss did not improve from 0.95332
# 98/98 [==============================] - 2s 17ms/step - loss: 0.7034 - accuracy: 0.7400 - val_loss: 0.9825 - val_accuracy: 0.6263 - lr: 3.1886e-05
# Epoch 139/226
# 98/98 [==============================] - ETA: 0s - loss: 0.7046 - accuracy: 0.7435
# Epoch 139: val_loss did not improve from 0.95332
# 98/98 [==============================] - 2s 16ms/step - loss: 0.7046 - accuracy: 0.7435 - val_loss: 0.9840 - val_accuracy: 0.6153 - lr: 3.1886e-05
# Epoch 140/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.7011 - accuracy: 0.7411
# Epoch 140: val_loss did not improve from 0.95332
# 98/98 [==============================] - 2s 18ms/step - loss: 0.7006 - accuracy: 0.7417 - val_loss: 0.9791 - val_accuracy: 0.6178 - lr: 3.1886e-05
# Epoch 141/226
# 95/98 [============================>.] - ETA: 0s - loss: 0.7032 - accuracy: 0.7419
# Epoch 141: val_loss did not improve from 0.95332
# 98/98 [==============================] - 2s 19ms/step - loss: 0.7034 - accuracy: 0.7418 - val_loss: 0.9730 - val_accuracy: 0.6271 - lr: 2.8698e-05
# Epoch 142/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.6994 - accuracy: 0.7434
# Epoch 142: val_loss did not improve from 0.95332
# 98/98 [==============================] - 2s 17ms/step - loss: 0.6990 - accuracy: 0.7436 - val_loss: 0.9825 - val_accuracy: 0.6297 - lr: 2.8698e-05
# Epoch 143/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.6937 - accuracy: 0.7446
# Epoch 143: val_loss did not improve from 0.95332
# 98/98 [==============================] - 2s 16ms/step - loss: 0.6937 - accuracy: 0.7444 - val_loss: 0.9822 - val_accuracy: 0.6288 - lr: 2.8698e-05
# Epoch 144/226
# 98/98 [==============================] - ETA: 0s - loss: 0.6953 - accuracy: 0.7436
# Epoch 144: val_loss did not improve from 0.95332
# 98/98 [==============================] - 2s 16ms/step - loss: 0.6953 - accuracy: 0.7436 - val_loss: 0.9698 - val_accuracy: 0.6220 - lr: 2.8698e-05
# Epoch 145/226
# 95/98 [============================>.] - ETA: 0s - loss: 0.6907 - accuracy: 0.7453
# Epoch 145: val_loss did not improve from 0.95332
# 98/98 [==============================] - 2s 17ms/step - loss: 0.6907 - accuracy: 0.7451 - val_loss: 0.9705 - val_accuracy: 0.6347 - lr: 2.8698e-05
# Epoch 146/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.6980 - accuracy: 0.7425
# Epoch 146: val_loss did not improve from 0.95332
# 98/98 [==============================] - 2s 16ms/step - loss: 0.6977 - accuracy: 0.7427 - val_loss: 0.9760 - val_accuracy: 0.6322 - lr: 2.8698e-05
# Epoch 147/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.6912 - accuracy: 0.7448
# Epoch 147: val_loss did not improve from 0.95332
# 98/98 [==============================] - 2s 17ms/step - loss: 0.6911 - accuracy: 0.7447 - val_loss: 0.9734 - val_accuracy: 0.6246 - lr: 2.8698e-05
# Epoch 148/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.6919 - accuracy: 0.7474
# Epoch 148: val_loss did not improve from 0.95332
# 98/98 [==============================] - 2s 18ms/step - loss: 0.6918 - accuracy: 0.7474 - val_loss: 0.9783 - val_accuracy: 0.6220 - lr: 2.8698e-05
# Epoch 149/226
# 98/98 [==============================] - ETA: 0s - loss: 0.6870 - accuracy: 0.7494
# Epoch 149: val_loss did not improve from 0.95332
# 98/98 [==============================] - 2s 19ms/step - loss: 0.6870 - accuracy: 0.7494 - val_loss: 0.9687 - val_accuracy: 0.6271 - lr: 2.8698e-05
# Epoch 150/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.6852 - accuracy: 0.7486
# Epoch 150: val_loss did not improve from 0.95332
# 98/98 [==============================] - 2s 17ms/step - loss: 0.6855 - accuracy: 0.7485 - val_loss: 0.9749 - val_accuracy: 0.6314 - lr: 2.8698e-05
# Epoch 151/226
# 98/98 [==============================] - ETA: 0s - loss: 0.6854 - accuracy: 0.7471
# Epoch 151: val_loss did not improve from 0.95332
# 98/98 [==============================] - 2s 16ms/step - loss: 0.6854 - accuracy: 0.7471 - val_loss: 0.9823 - val_accuracy: 0.6220 - lr: 2.8698e-05
# Epoch 152/226
# 98/98 [==============================] - ETA: 0s - loss: 0.6865 - accuracy: 0.7485
# Epoch 152: val_loss did not improve from 0.95332
# 98/98 [==============================] - 2s 17ms/step - loss: 0.6865 - accuracy: 0.7485 - val_loss: 0.9540 - val_accuracy: 0.6339 - lr: 2.8698e-05
# Epoch 153/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.6885 - accuracy: 0.7461
# Epoch 153: val_loss did not improve from 0.95332
# 98/98 [==============================] - 2s 17ms/step - loss: 0.6886 - accuracy: 0.7460 - val_loss: 0.9649 - val_accuracy: 0.6390 - lr: 2.8698e-05
# Epoch 154/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.6863 - accuracy: 0.7482
# Epoch 154: val_loss did not improve from 0.95332
# 98/98 [==============================] - 2s 16ms/step - loss: 0.6864 - accuracy: 0.7481 - val_loss: 0.9671 - val_accuracy: 0.6331 - lr: 2.8698e-05
# Epoch 155/226
# 98/98 [==============================] - ETA: 0s - loss: 0.6828 - accuracy: 0.7499
# Epoch 155: val_loss did not improve from 0.95332
# 98/98 [==============================] - 2s 16ms/step - loss: 0.6828 - accuracy: 0.7499 - val_loss: 0.9780 - val_accuracy: 0.6237 - lr: 2.8698e-05
# Epoch 156/226
# 95/98 [============================>.] - ETA: 0s - loss: 0.6856 - accuracy: 0.7486
# Epoch 156: val_loss did not improve from 0.95332
# 98/98 [==============================] - 2s 19ms/step - loss: 0.6852 - accuracy: 0.7488 - val_loss: 0.9696 - val_accuracy: 0.6373 - lr: 2.8698e-05
# Epoch 157/226
# ...
# 98/98 [==============================] - 2s 18ms/step - loss: 0.6676 - accuracy: 0.7524 - val_loss: 0.9561 - val_accuracy: 0.6364 - lr: 2.5828e-05
# Epoch 174/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.6719 - accuracy: 0.7557
# Epoch 174: val_loss did not improve from 0.95332
# 98/98 [==============================] - 2s 17ms/step - loss: 0.6725 - accuracy: 0.7556 - val_loss: 0.9535 - val_accuracy: 0.6381 - lr: 2.5828e-05
# Epoch 175/226
# 98/98 [==============================] - ETA: 0s - loss: 0.6625 - accuracy: 0.7556
# Epoch 175: val_loss did not improve from 0.95332
# 98/98 [==============================] - 2s 16ms/step - loss: 0.6625 - accuracy: 0.7556 - val_loss: 0.9591 - val_accuracy: 0.6288 - lr: 2.5828e-05
# Epoch 176/226
# 98/98 [==============================] - ETA: 0s - loss: 0.6694 - accuracy: 0.7530
# Epoch 176: val_loss did not improve from 0.95332
# 98/98 [==============================] - 2s 17ms/step - loss: 0.6694 - accuracy: 0.7530 - val_loss: 0.9567 - val_accuracy: 0.6280 - lr: 2.5828e-05
# Epoch 177/226
# 98/98 [==============================] - ETA: 0s - loss: 0.6631 - accuracy: 0.7546
# Epoch 177: val_loss did not improve from 0.95332
# 98/98 [==============================] - 2s 17ms/step - loss: 0.6631 - accuracy: 0.7546 - val_loss: 0.9650 - val_accuracy: 0.6280 - lr: 2.5828e-05
# Epoch 178/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.6660 - accuracy: 0.7566
# Epoch 178: val_loss did not improve from 0.95332
# 98/98 [==============================] - 2s 17ms/step - loss: 0.6657 - accuracy: 0.7569 - val_loss: 0.9694 - val_accuracy: 0.6246 - lr: 2.5828e-05
# Epoch 179/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.6620 - accuracy: 0.7570
# Epoch 179: val_loss improved from 0.95332 to 0.94986, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 22ms/step - loss: 0.6616 - accuracy: 0.7572 - val_loss: 0.9499 - val_accuracy: 0.6305 - lr: 2.5828e-05
# Epoch 180/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.6653 - accuracy: 0.7568
# Epoch 180: val_loss did not improve from 0.94986
# 98/98 [==============================] - 2s 19ms/step - loss: 0.6645 - accuracy: 0.7570 - val_loss: 0.9754 - val_accuracy: 0.6314 - lr: 2.5828e-05
# Epoch 181/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.6578 - accuracy: 0.7570
# Epoch 181: val_loss did not improve from 0.94986
# 98/98 [==============================] - 2s 17ms/step - loss: 0.6578 - accuracy: 0.7568 - val_loss: 0.9514 - val_accuracy: 0.6331 - lr: 2.3245e-05
# Epoch 182/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.6566 - accuracy: 0.7579
# Epoch 182: val_loss did not improve from 0.94986
# 98/98 [==============================] - 2s 16ms/step - loss: 0.6564 - accuracy: 0.7580 - val_loss: 0.9589 - val_accuracy: 0.6347 - lr: 2.3245e-05
# Epoch 183/226
# 95/98 [============================>.] - ETA: 0s - loss: 0.6552 - accuracy: 0.7598
# Epoch 183: val_loss did not improve from 0.94986
# 98/98 [==============================] - 2s 17ms/step - loss: 0.6555 - accuracy: 0.7598 - val_loss: 0.9536 - val_accuracy: 0.6271 - lr: 2.3245e-05
# Epoch 184/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.6564 - accuracy: 0.7592
# Epoch 184: val_loss did not improve from 0.94986
# 98/98 [==============================] - 2s 16ms/step - loss: 0.6571 - accuracy: 0.7589 - val_loss: 0.9605 - val_accuracy: 0.6432 - lr: 2.3245e-05
# Epoch 185/226
# 98/98 [==============================] - ETA: 0s - loss: 0.6563 - accuracy: 0.7590
# Epoch 185: val_loss did not improve from 0.94986
# 98/98 [==============================] - 2s 17ms/step - loss: 0.6563 - accuracy: 0.7590 - val_loss: 0.9644 - val_accuracy: 0.6212 - lr: 2.3245e-05
# Epoch 186/226
# 95/98 [============================>.] - ETA: 0s - loss: 0.6549 - accuracy: 0.7569
# Epoch 186: val_loss did not improve from 0.94986
# 98/98 [==============================] - 2s 17ms/step - loss: 0.6539 - accuracy: 0.7574 - val_loss: 0.9605 - val_accuracy: 0.6314 - lr: 2.3245e-05
# Epoch 187/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.6502 - accuracy: 0.7600
# Epoch 187: val_loss did not improve from 0.94986
# 98/98 [==============================] - 2s 18ms/step - loss: 0.6506 - accuracy: 0.7597 - val_loss: 0.9650 - val_accuracy: 0.6407 - lr: 2.3245e-05
# Epoch 188/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.6532 - accuracy: 0.7592
# Epoch 188: val_loss did not improve from 0.94986
# 98/98 [==============================] - 2s 18ms/step - loss: 0.6531 - accuracy: 0.7593 - val_loss: 0.9557 - val_accuracy: 0.6297 - lr: 2.3245e-05
# Epoch 189/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.6526 - accuracy: 0.7604
# Epoch 189: val_loss did not improve from 0.94986
# 98/98 [==============================] - 2s 17ms/step - loss: 0.6524 - accuracy: 0.7604 - val_loss: 0.9527 - val_accuracy: 0.6339 - lr: 2.3245e-05
# Epoch 190/226
# 95/98 [============================>.] - ETA: 0s - loss: 0.6503 - accuracy: 0.7623
# Epoch 190: val_loss did not improve from 0.94986
# 98/98 [==============================] - 2s 17ms/step - loss: 0.6514 - accuracy: 0.7620 - val_loss: 0.9566 - val_accuracy: 0.6381 - lr: 2.3245e-05
# Epoch 191/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.6548 - accuracy: 0.7604
# Epoch 191: val_loss did not improve from 0.94986
# 98/98 [==============================] - 2s 16ms/step - loss: 0.6545 - accuracy: 0.7604 - val_loss: 0.9504 - val_accuracy: 0.6347 - lr: 2.3245e-05
# Epoch 192/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.6483 - accuracy: 0.7644
# Epoch 192: val_loss did not improve from 0.94986
# 98/98 [==============================] - 2s 17ms/step - loss: 0.6491 - accuracy: 0.7642 - val_loss: 0.9512 - val_accuracy: 0.6398 - lr: 2.3245e-05
# Epoch 193/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.6556 - accuracy: 0.7589
# Epoch 193: val_loss did not improve from 0.94986
# 98/98 [==============================] - 2s 17ms/step - loss: 0.6555 - accuracy: 0.7589 - val_loss: 0.9559 - val_accuracy: 0.6373 - lr: 2.3245e-05
# Epoch 194/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.6458 - accuracy: 0.7627
# Epoch 194: val_loss did not improve from 0.94986
# 98/98 [==============================] - 2s 17ms/step - loss: 0.6461 - accuracy: 0.7626 - val_loss: 0.9646 - val_accuracy: 0.6280 - lr: 2.3245e-05
# Epoch 195/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.6513 - accuracy: 0.7590
# Epoch 195: val_loss did not improve from 0.94986
# 98/98 [==============================] - 2s 19ms/step - loss: 0.6513 - accuracy: 0.7589 - val_loss: 0.9579 - val_accuracy: 0.6322 - lr: 2.3245e-05
# Epoch 196/226
# 98/98 [==============================] - ETA: 0s - loss: 0.6476 - accuracy: 0.7628
# Epoch 196: val_loss did not improve from 0.94986
# 98/98 [==============================] - 2s 19ms/step - loss: 0.6476 - accuracy: 0.7628 - val_loss: 0.9518 - val_accuracy: 0.6364 - lr: 2.3245e-05
# Epoch 197/226
# 98/98 [==============================] - ETA: 0s - loss: 0.6518 - accuracy: 0.7615
# Epoch 197: val_loss improved from 0.94986 to 0.94601, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 23ms/step - loss: 0.6518 - accuracy: 0.7615 - val_loss: 0.9460 - val_accuracy: 0.6314 - lr: 2.3245e-05
# Epoch 198/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.6494 - accuracy: 0.7629
# Epoch 198: val_loss did not improve from 0.94601
# 98/98 [==============================] - 2s 17ms/step - loss: 0.6489 - accuracy: 0.7630 - val_loss: 0.9537 - val_accuracy: 0.6407 - lr: 2.3245e-05
# Epoch 199/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.6417 - accuracy: 0.7633
# Epoch 199: val_loss did not improve from 0.94601
# 98/98 [==============================] - 2s 16ms/step - loss: 0.6429 - accuracy: 0.7629 - val_loss: 0.9582 - val_accuracy: 0.6339 - lr: 2.3245e-05
# Epoch 200/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.6442 - accuracy: 0.7613
# Epoch 200: val_loss did not improve from 0.94601
# 98/98 [==============================] - 2s 17ms/step - loss: 0.6439 - accuracy: 0.7613 - val_loss: 0.9583 - val_accuracy: 0.6305 - lr: 2.3245e-05
# Epoch 201/226
# 98/98 [==============================] - ETA: 0s - loss: 0.6383 - accuracy: 0.7653
# Epoch 201: val_loss did not improve from 0.94601
# 98/98 [==============================] - 2s 17ms/step - loss: 0.6383 - accuracy: 0.7653 - val_loss: 0.9601 - val_accuracy: 0.6314 - lr: 2.0921e-05
# Epoch 202/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.6426 - accuracy: 0.7635
# Epoch 202: val_loss did not improve from 0.94601
# 98/98 [==============================] - 2s 17ms/step - loss: 0.6425 - accuracy: 0.7638 - val_loss: 0.9603 - val_accuracy: 0.6356 - lr: 2.0921e-05
# Epoch 203/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.6498 - accuracy: 0.7596
# Epoch 203: val_loss did not improve from 0.94601
# 98/98 [==============================] - 2s 19ms/step - loss: 0.6481 - accuracy: 0.7605 - val_loss: 0.9497 - val_accuracy: 0.6297 - lr: 2.0921e-05
# Epoch 204/226
# 95/98 [============================>.] - ETA: 0s - loss: 0.6408 - accuracy: 0.7628
# Epoch 204: val_loss did not improve from 0.94601
# 98/98 [==============================] - 2s 19ms/step - loss: 0.6397 - accuracy: 0.7636 - val_loss: 0.9610 - val_accuracy: 0.6347 - lr: 2.0921e-05
# Epoch 205/226
# 98/98 [==============================] - ETA: 0s - loss: 0.6417 - accuracy: 0.7641
# Epoch 205: val_loss did not improve from 0.94601
# 98/98 [==============================] - 2s 16ms/step - loss: 0.6417 - accuracy: 0.7641 - val_loss: 0.9552 - val_accuracy: 0.6347 - lr: 2.0921e-05
# Epoch 206/226
# 98/98 [==============================] - ETA: 0s - loss: 0.6404 - accuracy: 0.7642
# Epoch 206: val_loss did not improve from 0.94601
# 98/98 [==============================] - 2s 17ms/step - loss: 0.6404 - accuracy: 0.7642 - val_loss: 0.9606 - val_accuracy: 0.6398 - lr: 2.0921e-05
# Epoch 207/226
# 95/98 [============================>.] - ETA: 0s - loss: 0.6343 - accuracy: 0.7685
# Epoch 207: val_loss did not improve from 0.94601
# 98/98 [==============================] - 2s 16ms/step - loss: 0.6349 - accuracy: 0.7682 - val_loss: 0.9495 - val_accuracy: 0.6339 - lr: 2.0921e-05
# Epoch 208/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.6388 - accuracy: 0.7637
# Epoch 208: val_loss did not improve from 0.94601
# 98/98 [==============================] - 2s 16ms/step - loss: 0.6385 - accuracy: 0.7638 - val_loss: 0.9520 - val_accuracy: 0.6364 - lr: 2.0921e-05
# Epoch 209/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.6349 - accuracy: 0.7648
# Epoch 209: val_loss did not improve from 0.94601
# 98/98 [==============================] - 2s 17ms/step - loss: 0.6353 - accuracy: 0.7646 - val_loss: 0.9571 - val_accuracy: 0.6339 - lr: 2.0921e-05
# Epoch 210/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.6363 - accuracy: 0.7654
# Epoch 210: val_loss did not improve from 0.94601
# 98/98 [==============================] - 2s 17ms/step - loss: 0.6365 - accuracy: 0.7651 - val_loss: 0.9482 - val_accuracy: 0.6322 - lr: 2.0921e-05
# Epoch 211/226
# 98/98 [==============================] - ETA: 0s - loss: 0.6386 - accuracy: 0.7648
# Epoch 211: val_loss did not improve from 0.94601
# 98/98 [==============================] - 2s 19ms/step - loss: 0.6386 - accuracy: 0.7648 - val_loss: 0.9569 - val_accuracy: 0.6390 - lr: 2.0921e-05
# Epoch 212/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.6392 - accuracy: 0.7643
# Epoch 212: val_loss did not improve from 0.94601
# 98/98 [==============================] - 2s 18ms/step - loss: 0.6378 - accuracy: 0.7648 - val_loss: 0.9569 - val_accuracy: 0.6364 - lr: 2.0921e-05
# Epoch 213/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.6406 - accuracy: 0.7660
# Epoch 213: val_loss did not improve from 0.94601
# 98/98 [==============================] - 2s 16ms/step - loss: 0.6404 - accuracy: 0.7662 - val_loss: 0.9518 - val_accuracy: 0.6432 - lr: 2.0921e-05
# Epoch 214/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.6323 - accuracy: 0.7664
# Epoch 214: val_loss improved from 0.94601 to 0.94305, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 22ms/step - loss: 0.6320 - accuracy: 0.7668 - val_loss: 0.9431 - val_accuracy: 0.6373 - lr: 2.0921e-05
# Epoch 215/226
# 98/98 [==============================] - ETA: 0s - loss: 0.6356 - accuracy: 0.7646
# Epoch 215: val_loss improved from 0.94305 to 0.94083, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 17ms/step - loss: 0.6356 - accuracy: 0.7646 - val_loss: 0.9408 - val_accuracy: 0.6347 - lr: 2.0921e-05
# Epoch 216/226
# 98/98 [==============================] - ETA: 0s - loss: 0.6355 - accuracy: 0.7675
# Epoch 216: val_loss did not improve from 0.94083
# 98/98 [==============================] - 2s 16ms/step - loss: 0.6355 - accuracy: 0.7675 - val_loss: 0.9533 - val_accuracy: 0.6407 - lr: 2.0921e-05
# Epoch 217/226
# 95/98 [============================>.] - ETA: 0s - loss: 0.6342 - accuracy: 0.7644
# Epoch 217: val_loss did not improve from 0.94083
# 98/98 [==============================] - 2s 16ms/step - loss: 0.6353 - accuracy: 0.7637 - val_loss: 0.9574 - val_accuracy: 0.6364 - lr: 2.0921e-05
# Epoch 218/226
# 98/98 [==============================] - ETA: 0s - loss: 0.6314 - accuracy: 0.7668
# Epoch 218: val_loss did not improve from 0.94083
# 98/98 [==============================] - 2s 18ms/step - loss: 0.6314 - accuracy: 0.7668 - val_loss: 0.9429 - val_accuracy: 0.6339 - lr: 2.0921e-05
# Epoch 219/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.6326 - accuracy: 0.7666
# Epoch 219: val_loss improved from 0.94083 to 0.93514, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 20ms/step - loss: 0.6324 - accuracy: 0.7667 - val_loss: 0.9351 - val_accuracy: 0.6390 - lr: 2.0921e-05
# Epoch 220/226
# 95/98 [============================>.] - ETA: 0s - loss: 0.6298 - accuracy: 0.7677
# Epoch 220: val_loss improved from 0.93514 to 0.93406, saving model to ./CNN1-models/0328-t4.hdf5
# 98/98 [==============================] - 2s 18ms/step - loss: 0.6308 - accuracy: 0.7672 - val_loss: 0.9341 - val_accuracy: 0.6364 - lr: 2.0921e-05
# Epoch 221/226
# 98/98 [==============================] - ETA: 0s - loss: 0.6339 - accuracy: 0.7639
# Epoch 221: val_loss did not improve from 0.93406
# 98/98 [==============================] - 2s 16ms/step - loss: 0.6339 - accuracy: 0.7639 - val_loss: 0.9409 - val_accuracy: 0.6407 - lr: 1.8829e-05
# Epoch 222/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.6268 - accuracy: 0.7681
# Epoch 222: val_loss did not improve from 0.93406
# 98/98 [==============================] - 2s 16ms/step - loss: 0.6268 - accuracy: 0.7681 - val_loss: 0.9512 - val_accuracy: 0.6331 - lr: 1.8829e-05
# Epoch 223/226
# 95/98 [============================>.] - ETA: 0s - loss: 0.6276 - accuracy: 0.7695
# Epoch 223: val_loss did not improve from 0.93406
# 98/98 [==============================] - 2s 17ms/step - loss: 0.6261 - accuracy: 0.7697 - val_loss: 0.9486 - val_accuracy: 0.6347 - lr: 1.8829e-05
# Epoch 224/226
# 97/98 [============================>.] - ETA: 0s - loss: 0.6241 - accuracy: 0.7688
# Epoch 224: val_loss did not improve from 0.93406
# 98/98 [==============================] - 2s 16ms/step - loss: 0.6242 - accuracy: 0.7687 - val_loss: 0.9543 - val_accuracy: 0.6347 - lr: 1.8829e-05
# Epoch 225/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.6275 - accuracy: 0.7685
# Epoch 225: val_loss did not improve from 0.93406
# 98/98 [==============================] - 2s 16ms/step - loss: 0.6278 - accuracy: 0.7684 - val_loss: 0.9377 - val_accuracy: 0.6398 - lr: 1.8829e-05
# Epoch 226/226
# 96/98 [============================>.] - ETA: 0s - loss: 0.6298 - accuracy: 0.7666
# Epoch 226: val_loss did not improve from 0.93406
# 98/98 [==============================] - 2s 18ms/step - loss: 0.6302 - accuracy: 0.7662 - val_loss: 0.9519 - val_accuracy: 0.6356 - lr: 1.8829e-05

# %%
plt.plot(cnnhistory.history['loss'])
plt.plot(cnnhistory.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
plt.plot(cnnhistory.history['accuracy'])
plt.plot(cnnhistory.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('acc')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %%
loss, acc = model.evaluate(X_test_cnn, y_test_e_cnn)
print("Restored model, accuracy: {:5.2f}%".format(100*acc))
# Out:
# 37/37 [==============================] - 1s 16ms/step - loss: 0.9519 - accuracy: 0.6356
# Restored model, accuracy: 63.56%

# %%
# model_1 = 'T2-1-0328-aug-t1-r4' + '-' +str(acc)
acc2 = acc * 10000
acc_formatted = '{:04d}'.format(int(acc2))
model_1 = 'T2-1-0328-aug-t4' + '-' + acc_formatted
# model_2 = 'T2-2-0320-aug-v3d4-v3r2'
model_name = model_1 + '.h5'
save_dir = './CNN1-models'
# Save model and weights
if not os.path.isdir(save_dir):
    os.makedirs(save_dir)
model_path = os.path.join(save_dir, model_name)
model.save(model_path)
print('Saved trained model at %s ' % model_path)


# model_name = model_2 + '.h5'
# save_dir = './CNN2-models'
# # Save model and weights
# if not os.path.isdir(save_dir):
#     os.makedirs(save_dir)
# model_path = os.path.join(save_dir, model_name)
# model2.save(model_path)
# print('Saved trained model at %s ' % model_path)
# Out:
# Saved trained model at ./CNN1-models/T2-1-0328-aug-t4-6355.h5

# %%
from google.colab import runtime
runtime.unassign()
